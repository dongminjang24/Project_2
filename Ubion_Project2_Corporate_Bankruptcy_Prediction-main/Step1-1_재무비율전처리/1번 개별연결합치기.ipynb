# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv("./datasets/연간보고서19전처리전.csv", encoding='CP949')

# %%
## 0,1,2열은 회사명 코드 회계날짜라 불필요
column_list=data1.columns[3:]

# %%
## 데이터가 자본(연걸) 자본(개별) 순서로 되어있다는 가정하에 연결 데이터가 nan일 경우 개별로 대체
from tqdm import tqdm
import numpy as np
for i in tqdm(np.arange(0,len(column_list),2)):
    for j in range(data1.shape[0]):
        if np.isnan(data1[column_list[i]][j]) :
            data1[column_list[i]][j]=data1[column_list[i+1]][j]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]C:\Users\dbswo\AppData\Local\Temp\ipykernel_16696\2405746084.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[column_list[i]][j]=data1[column_list[i+1]][j]
# 100%|██████████| 8/8 [00:00<00:00, 10.16it/s]

# %%
## 개별재무제표 재무비율 제거
data1=data1.drop(data1.columns[np.arange(4,20,2)],axis=1)

# %%
columns_ = ['회사명', '거래소코드', '회계년도', '자산', '영업이익', '부채', '자본', '매출액', '유동자산', '유동부채', '이익잉여금']
data1.columns = columns_
data1.to_csv('./datasets/연간보고서19.csv',encoding='CP949', index=None)
# Out:
#              회사명   거래소코드     회계년도           자산        영업이익           부채  \
# 0       (주)CMG제약   58820  2019/12  192243166.0   2603774.0   12084883.0
# 1        (주)ES큐브   50120  2019/12  463958680.0    587700.0  389920168.0
# 2         (주)가비아   79940  2019/12  199916131.0   4889113.0   64956993.0
# 3        (주)가온칩스  399720  2019/12   16013325.0   3080011.0    7856129.0
# 4     (주)강스템바이오텍  217730  2019/12  113643697.0 -19411148.0   44924460.0
# ...          ...     ...      ...          ...         ...          ...
# 1503    효성오앤비(주)   97870  2019/06   70203765.0   1331706.0    6641029.0
# 1504     휴림로봇(주)   90710  2019/12   42734247.0  -3879766.0   14263432.0
# 1505     휴마시스(주)  205470  2019/12   36487811.0   -875264.0   21243825.0
# 1506       휴젤(주)  145020  2019/12  894690014.0  41865498.0  150419075.0
# 1507     흥구석유(주)   24060  2019/12   83661499.0    500763.0    6660240.0
#
#                자본          매출액         유동자산         유동부채        이익잉여금
# 0     180158283.0   58622681.0  150584066.0    9306387.0    5054709.0
# 1      74038512.0   43708239.0  359030693.0  230135454.0    6015932.0
# 2     134959139.0  148306878.0   86880807.0   43098923.0   70637536.0
# 3       8157196.0   27790678.0   13586283.0    7856129.0    7957196.0
# 4      68719236.0    6004584.0   55408095.0   20598774.0  -77231627.0
# ...           ...          ...          ...          ...          ...
# 1503   63562735.0   28376911.0   36812995.0    5071188.0   50317324.0
# 1504   28470815.0   17620760.0   26232830.0   13239812.0  -46543830.0
# 1505   15243986.0    9150652.0   25771471.0   15471882.0   -9240555.0
# 1506  744270939.0  204567625.0  640910847.0   37568296.0  768284514.0
# 1507   77001259.0  150668735.0   22619714.0    4660149.0   40649728.0
#
# [1508 rows x 11 columns]
