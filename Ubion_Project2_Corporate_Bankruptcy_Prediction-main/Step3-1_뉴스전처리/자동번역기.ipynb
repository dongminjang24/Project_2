# %%
#from selenium import webdriver
#from bs4 import BeautifulSoup

#import requests
import re
import pandas as pd
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\ubion\Corporate_Bankruptcy_Prediction\Step3_뉴스전처리\자동번역기.ipynb Cell 1' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=0'>1</a> #from selenium import webdriver
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=1'>2</a> #from bs4 import BeautifulSoup
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=2'>3</a>
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=3'>4</a> #import requests
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=4'>5</a> import re
# ----> <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=5'>6</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/ubion/Corporate_Bankruptcy_Prediction/Step3_%EB%89%B4%EC%8A%A4%EC%A0%84%EC%B2%98%EB%A6%AC/%EC%9E%90%EB%8F%99%EB%B2%88%EC%97%AD%EA%B8%B0.ipynb#ch0000000?line=6'>7</a> import time
#
# ModuleNotFoundError: No module named 'pandas'

# %%
상폐기업뉴스 = pd.read_csv('../전처리후/정상기업뉴스전처리추가.csv')
# 상폐기업뉴스.drop('Unnamed: 0', axis=1, inplace=True)

# pattern1 = r'\([^)]*\)'
# pattern2 = r"\[([^]]+)\]"

# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in 상폐기업뉴스['뉴스기사본문']]
# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in 상폐기업뉴스['뉴스기사본문전처리']]
# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in 상폐기업뉴스['뉴스기사본문전처리']]
# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in 상폐기업뉴스['뉴스기사본문전처리']]
# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in 상폐기업뉴스['뉴스기사본문전처리']]
# 상폐기업뉴스['뉴스기사본문전처리'] = [re.sub('[/+]', '', s) for s in 상폐기업뉴스['뉴스기사본문전처리']]
# 상폐기업뉴스.drop('뉴스기사본문', axis=1, inplace=True)
상폐기업뉴스
# Out:
# KeyboardInterrupt

# %%
상폐기업뉴스["기사본문번역"]=상폐기업뉴스["기사제목"]
상폐기업뉴스
# Out:
#           기업                 기사발행일                                    기사제목  \
# 0     씨제이이엔엠   2011.08.16. 오전 9:21                         코스닥, IT부품주 '훨훨'
# 1     씨제이이엔엠   2011.06.08. 오전 7:58                         장마감후 주요 종목뉴스-7일
# 2     씨제이이엔엠   2011.06.07. 오후 5:31                     CJ, CJ푸드서비스 계열사서 제외
# 3     씨제이이엔엠  2011.03.12. 오전 10:01                현대카드ㆍ현대캐피탈, 사업성공 프로그램 후원
# 4     씨제이이엔엠   2011.03.11. 오후 4:21                 "27일까지 사업성공 스토리에 도전하세요"
# ...      ...                   ...                                     ...
# 4382   에이치엘비   2020.09.22. 오후 2:57     "이래도 불법 공매도가 아니라고?"...에이치엘비 주주들 뿔났다
# 4383   에이치엘비  2020.12.30. 오전 11:16  리보세라닙 병용 식도암 임상, 방사선 병행시 3명중 1명 `완전관해`
# 4384   에이치엘비   2020.12.14. 오전 9:59     넥스트사이언스 관계사 나노젠 "내년 5월 코로나백신 양산 계획"
# 4385   에이치엘비   2020.12.14. 오전 9:28    넥스트사이언스 관계사 나노젠 “코로나 백신 내년 5월 양산 계획”
# 4386   에이치엘비   2020.12.14. 오전 9:39       넥스트사이언스 "나노젠, 코로나 백신 내년 5월 양산 계획"
#
#                                               뉴스기사본문전처리  \
# 0     일 코스닥 시장에서는 부품주들이 강세를 보이고 있다. 특히 구글의 모토로라 인수 소...
# 1     코스피 시장는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드...
# 2     는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드서비스의 자...
# 3     현대카드현대캐피탈은 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# 4     현대카드현대캐피탈이 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# ...                                                 ...
# 4382  에이치엘비 주주들 공매도세력이 개월간 주가 하락 시세 조정 주장거래소 감시시스템 주...
# 4383   에이치엘비는 중국에서 수행된 리보세라닙 병용 임상 결과 위암 식도암에서 다시 한번...
# 4384   넥스트사이언스는 관계사이자 베트남 기업으로 유일하게 코로나 백신 임상을 승인받은 ...
# 4385  사진넥스트사이언스 재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌...
# 4386   재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌어 변종이 심한 ...
#
#                                       기사본문번역
# 0                            코스닥, IT부품주 '훨훨'
# 1                            장마감후 주요 종목뉴스-7일
# 2                        CJ, CJ푸드서비스 계열사서 제외
# 3                   현대카드ㆍ현대캐피탈, 사업성공 프로그램 후원
# 4                    "27일까지 사업성공 스토리에 도전하세요"
# ...                                      ...
# 4382     "이래도 불법 공매도가 아니라고?"...에이치엘비 주주들 뿔났다
# 4383  리보세라닙 병용 식도암 임상, 방사선 병행시 3명중 1명 `완전관해`
# 4384     넥스트사이언스 관계사 나노젠 "내년 5월 코로나백신 양산 계획"
# 4385    넥스트사이언스 관계사 나노젠 “코로나 백신 내년 5월 양산 계획”
# 4386       넥스트사이언스 "나노젠, 코로나 백신 내년 5월 양산 계획"
#
# [4387 rows x 5 columns]

# %%
# driver = webdriver.Chrome(r"C:\Users\dbswo\OneDrive\Desktop\논문복원\크롤링\chromedriver.exe")
driver = webdriver.Chrome()
url = "https://papago.naver.com/"
driver.get(url)

#기사번역=[]
for 뉴스 in 상폐기업뉴스['뉴스기사본문전처리'].loc[4136:]:

    response = requests.get(url)
    soup = BeautifulSoup(response.text, "lxml")

    time.sleep(2)

    input = driver.find_element('xpath', '//*[@id="txtSource"]')
    #input = driver.find_element_by_xpath('//*[@id="txtSource"]')
    input.clear()
    input.send_keys(뉴스)

    button = driver.find_element('xpath', '//*[@id="btnTranslate"]')
    #button = driver.find_element_by_xpath('//*[@id="btnTranslate"]')
    button.click()
    time.sleep(7)

    result = driver.find_element('xpath', '//*[@id="txtTarget"]/span').text
    #result = driver.find_element_by_xpath('//*[@id="txtTarget"]/span').text
    기사번역.append(result)


상폐기업뉴스['기사본문번역']  = 기사번역
상폐기업뉴스
# Out:
#           기업                 기사발행일                                    기사제목  \
# 0     씨제이이엔엠   2011.08.16. 오전 9:21                         코스닥, IT부품주 '훨훨'
# 1     씨제이이엔엠   2011.06.08. 오전 7:58                         장마감후 주요 종목뉴스-7일
# 2     씨제이이엔엠   2011.06.07. 오후 5:31                     CJ, CJ푸드서비스 계열사서 제외
# 3     씨제이이엔엠  2011.03.12. 오전 10:01                현대카드ㆍ현대캐피탈, 사업성공 프로그램 후원
# 4     씨제이이엔엠   2011.03.11. 오후 4:21                 "27일까지 사업성공 스토리에 도전하세요"
# ...      ...                   ...                                     ...
# 4382   에이치엘비   2020.09.22. 오후 2:57     "이래도 불법 공매도가 아니라고?"...에이치엘비 주주들 뿔났다
# 4383   에이치엘비  2020.12.30. 오전 11:16  리보세라닙 병용 식도암 임상, 방사선 병행시 3명중 1명 `완전관해`
# 4384   에이치엘비   2020.12.14. 오전 9:59     넥스트사이언스 관계사 나노젠 "내년 5월 코로나백신 양산 계획"
# 4385   에이치엘비   2020.12.14. 오전 9:28    넥스트사이언스 관계사 나노젠 “코로나 백신 내년 5월 양산 계획”
# 4386   에이치엘비   2020.12.14. 오전 9:39       넥스트사이언스 "나노젠, 코로나 백신 내년 5월 양산 계획"
#
#                                               뉴스기사본문전처리  \
# 0     일 코스닥 시장에서는 부품주들이 강세를 보이고 있다. 특히 구글의 모토로라 인수 소...
# 1     코스피 시장는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드...
# 2     는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드서비스의 자...
# 3     현대카드현대캐피탈은 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# 4     현대카드현대캐피탈이 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# ...                                                 ...
# 4382  에이치엘비 주주들 공매도세력이 개월간 주가 하락 시세 조정 주장거래소 감시시스템 주...
# 4383   에이치엘비는 중국에서 수행된 리보세라닙 병용 임상 결과 위암 식도암에서 다시 한번...
# 4384   넥스트사이언스는 관계사이자 베트남 기업으로 유일하게 코로나 백신 임상을 승인받은 ...
# 4385  사진넥스트사이언스 재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌...
# 4386   재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌어 변종이 심한 ...
#
#                                                  기사본문번역
# 0     Parts stocks are strong in the Japanese KOSDAQ...
# 1     The KOSPI market made a public announcement th...
# 2     The company announced that it will exclude foo...
# 3     Hyundai Card Hyundai Capital announced that it...
# 4     Hyundai Card Hyundai Capital sponsors a realit...
# ...                                                 ...
# 4382  HLB shareholders are raising suspicions that i...
# 4383  HLB announced that it once again secured stati...
# 4384  Next Science announced that Nanogen, the only ...
# 4385  Nanocobox, made from photoNextScience recombin...
# 4386  Nanocobox made through recombinant protein fra...
#
# [4387 rows x 5 columns]

# %%
상폐기업뉴스
# Out:
#           기업                 기사발행일                                    기사제목  \
# 0     씨제이이엔엠   2011.08.16. 오전 9:21                         코스닥, IT부품주 '훨훨'
# 1     씨제이이엔엠   2011.06.08. 오전 7:58                         장마감후 주요 종목뉴스-7일
# 2     씨제이이엔엠   2011.06.07. 오후 5:31                     CJ, CJ푸드서비스 계열사서 제외
# 3     씨제이이엔엠  2011.03.12. 오전 10:01                현대카드ㆍ현대캐피탈, 사업성공 프로그램 후원
# 4     씨제이이엔엠   2011.03.11. 오후 4:21                 "27일까지 사업성공 스토리에 도전하세요"
# ...      ...                   ...                                     ...
# 4382   에이치엘비   2020.09.22. 오후 2:57     "이래도 불법 공매도가 아니라고?"...에이치엘비 주주들 뿔났다
# 4383   에이치엘비  2020.12.30. 오전 11:16  리보세라닙 병용 식도암 임상, 방사선 병행시 3명중 1명 `완전관해`
# 4384   에이치엘비   2020.12.14. 오전 9:59     넥스트사이언스 관계사 나노젠 "내년 5월 코로나백신 양산 계획"
# 4385   에이치엘비   2020.12.14. 오전 9:28    넥스트사이언스 관계사 나노젠 “코로나 백신 내년 5월 양산 계획”
# 4386   에이치엘비   2020.12.14. 오전 9:39       넥스트사이언스 "나노젠, 코로나 백신 내년 5월 양산 계획"
#
#                                               뉴스기사본문전처리  \
# 0     일 코스닥 시장에서는 부품주들이 강세를 보이고 있다. 특히 구글의 모토로라 인수 소...
# 1     코스피 시장는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드...
# 2     는 법인청산에 따라 푸드서비스를 계열사에서 제외한다고 일 공시했다. 푸드서비스의 자...
# 3     현대카드현대캐피탈은 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# 4     현대카드현대캐피탈이 성공을 향해 열정적으로 도전하는 개인사업자들의 이야기를 담은 리...
# ...                                                 ...
# 4382  에이치엘비 주주들 공매도세력이 개월간 주가 하락 시세 조정 주장거래소 감시시스템 주...
# 4383   에이치엘비는 중국에서 수행된 리보세라닙 병용 임상 결과 위암 식도암에서 다시 한번...
# 4384   넥스트사이언스는 관계사이자 베트남 기업으로 유일하게 코로나 백신 임상을 승인받은 ...
# 4385  사진넥스트사이언스 재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌...
# 4386   재조합 단백질 조각을 통해 만든 나노코박스는 높은 면역반응을 이끌어 변종이 심한 ...
#
#                                                  기사본문번역
# 0     Parts stocks are strong in the Japanese KOSDAQ...
# 1     The KOSPI market made a public announcement th...
# 2     The company announced that it will exclude foo...
# 3     Hyundai Card Hyundai Capital announced that it...
# 4     Hyundai Card Hyundai Capital sponsors a realit...
# ...                                                 ...
# 4382  HLB shareholders are raising suspicions that i...
# 4383  HLB announced that it once again secured stati...
# 4384  Next Science announced that Nanogen, the only ...
# 4385  Nanocobox, made from photoNextScience recombin...
# 4386  Nanocobox made through recombinant protein fra...
#
# [4387 rows x 5 columns]

# %%
dd = pd.DataFrame(기사번역)
dd.to_csv('번역1차.csv', index=None)

# %%
상폐기업뉴스.to_csv('../감성분석/정상기업번역파일추가.csv', index=None, encoding='utf-8-sig')
