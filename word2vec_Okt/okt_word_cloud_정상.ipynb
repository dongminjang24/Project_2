# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np
import re
from eunjeon import Mecab

# %%
정상기업 = pd.read_csv('./data/정상기업뉴스.csv')
data=정상기업

# %%
data[:5]
# Out:
#        기업                기사발행일                     기사제목  \
# 0  씨제이이엔엠  2011.12.13. 오전 8:24  씨제이이엔엠, 유형자산 취득 후 처분 예정
# 1  씨제이이엔엠  2011.08.16. 오전 9:21          코스닥, IT부품주 '훨훨'
# 2  씨제이이엔엠  2011.06.08. 오전 7:58          장마감후 주요 종목뉴스-7일
# 3  씨제이이엔엠  2011.06.07. 오후 5:31      CJ, CJ푸드서비스 계열사서 제외
# 4  씨제이이엔엠  2011.11.17. 오전 8:47  시초가 소폭 하락 예상 - 코스닥 동시호가
#
#                                               뉴스기사본문
# 0  씨제이이엔엠은 1276억 7200만원 규모의 유형자산을 취득한다고 13일 공시했다....
# 1  16일 코스닥 시장에서는 IT부품주들이 강세를 보이고 있다. 특히 구글의 모토로라 ...
# 2  [머니투데이 정영일 기자]◇코스피 시장\n△CJ는 법인청산에 따라 CJ푸드서비스를 ...
# 3  [머니투데이 김선주 기자]CJ는 법인청산에 따라 CJ푸드서비스를 계열사에서 제외한다...
# 4  17일 코스닥 시장은 소폭 하락 출발이 예상된다.\n\n코스닥 시장은 현재 시가총액...

# %%
제거할기사제목 = ['증시 일정', '증시일정', '장마감후', '장 마감 후', '장마감공시', '증시 캘린더', '재송', '투자정보', \
    '코스닥 기업공시', '장중 주요', '코스닥 3분기 결산', '주요 뉴스 및 공시', '기업공시',' 기업 공시', '장 종료 후', \
        '특징주A/S', '주요 정보', '오전 공시', '투자정보', '기업 공시', '오늘의 메모', '재테크 캘린더', '추천주 정리', '희망복원 주식클리닉', \
        '\d{1,2}월 \d{1,2}일', '오늘의 주요 공시', '코스닥 공시', '코스닥 메모', '대박 공모주', '<표>', '오늘의 리포트', \
        '공략주', '주식상담소', '주식왕 따라잡기', '주식컨설팅', '\d{4} 증시', '춤추는 테마주', '개장시황', \
        '폭등신호 터진', '대폭등', '매드머니', '주담과 Q&A', '굿바이 \d{4}', '지금 당장 사라', '폭등주', \
        '\d{4}%', '김정일 사망', '종목대탐험', '종목신호등', 'VIP CLUB', '수급유망주', '기상도', '중소형주', \
        '국민주식고충처리반', '유망주', '머니Q', '시초가잡아라', '기관 Q&A', '부동산에 투자하려면', '베스트애널리스트', \
        '코스닥협회장 취임', '코스닥협회', '부동산에 투자하는 방법', '국가품질 경영대회', '증시일정', '머니Q', '추천종목', '티타임 공략주', \
        '수급유망주', '종목배틀', '\d{4} 증시 결산', '기업설명회', '종목신호등', 'VIP CLUB 추천주', '내일장 공략주 10선', '주간컨센서스동향', \
        '주담과 Q&A', '조회공시', '주가급등 사유', '관련株들', '게임株', '이시각 Up&Down', '장내 매도', '[인사]', '증시기상도', \
        '[재송]', '마감시황', '주식부자 속출', '교육주', '티타임 공략주', '\d{1,2}일 증권사 추천종목', '기업IR소식', '[승부주]']
# 제거제목리스트=[]
제거제목리스트 = '|'.join(제거할기사제목)
data_unique = data.drop_duplicates(['뉴스기사본문'])
data_result = data_unique[~data_unique['기사제목'].str.contains(제거제목리스트, na=False, case=False)]
#data_result.to_csv('dd.csv')
pattern1 = r'\([^)]*\)'
#pattern2 = r'\[[^)]*\]'
pattern2 = r"\[([^]]+)\]"



# data_unique['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_unique['뉴스기사본문']]
# data_unique['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique
# data_unique.to_csv('dd.csv', index=None)





data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]
data_result
data_result.to_csv('dd.csv', index=None)
# Out:
# C:\Users\jangd\AppData\Local\Temp\ipykernel_27748\696962634.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_27748\696962634.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_27748\696962634.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_27748\696962634.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_27748\696962634.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]

# %%
train_data = pd.read_csv('./dd.csv')

# %%
# 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 형태소 분석기 mecab를 사용한 토큰화 작업 (다소 시간 소요)

mecab = Mecab()
tokenized_data = []
output=[]
for sentence in train_data['뉴스기사본문전처리']:
    temp_X = mecab.nouns(sentence)  # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords]  # 불용어 제거

    tokenized_data.append(temp_X)

# %% [markdown]
# 한글자 제거

# %%
remove_one_word=[]
for j in range(len(tokenized_data)):
    a=[x for x in tokenized_data[j] if len(x)>1]
    remove_one_word.append(a)

# %%
remove_one_word
len(remove_one_word)
list_text_1=sum(remove_one_word, [])

# %%
list_text_1
# Out:
# ['씨제이',
#  '규모',
#  '유형',
#  '자산',
#  '취득',
#  '공시',
#  '판교',
#  '도시',
#  '특별',
#  '계획',
#  '구역',
#  '중심',
#  '상업',
#  '지내',
#  '신축',
#  '예정',
#  '건물',
#  '취득',
#  '목적',
#  '제자',
#  '처분',
#  '흡수',
#  '합병',
#  '미디어',
#  '방송',
#  '사옥',
#  '신축',
#  '목적',
#  '판교',
#  '복합',
#  '사업',
#  '컨소시엄',
#  '알파',
#  '시티',
#  '출자',
#  '합병',
#  '해당',
#  '방송',
#  '사옥',
#  '신축',
#  '필요',
#  '해당',
#  '자산',
#  '매입',
#  '제자',
#  '처분',
#  '예정',
#  '처분',
#  '상대방',
#  '확정',
#  '대로',
#  '공시',
#  '조선',
#  '비즈',
#  '뉴스',
#  '삼성',
#  '전자',
#  '업계',
#  '리더',
#  '휴가',
#  '이유',
#  '한국',
#  '증시',
#  '상장',
#  '중국',
#  '기업',
#  '섰다',
#  '건설사',
#  '저작',
#  '등록',
#  '이유',
#  '남양유업',
#  '돌풍',
#  '조억',
#  '커피',
#  '믹스',
#  '시장',
#  '요동',
#  '코스닥',
#  '시장',
#  '소폭',
#  '하락',
#  '출발',
#  '예상',
#  '코스닥',
#  '시장',
#  '시가총액',
#  '상위',
#  '종목',
#  '매도',
#  '우위',
#  '종목',
#  '다수',
#  '판단',
#  '시가총액',
#  '상위',
#  '종목',
#  '씨제이',
#  '에스에프',
#  '백스',
#  '산하이',
#  '메탈',
#  '매수세',
#  '유입',
#  '업종',
#  '기계',
#  '장비',
#  '인터넷',
#  '금융',
#  '금속',
#  '상대',
#  '강세',
#  '조선',
#  '비즈',
#  '뉴스',
#  '삼성전자',
#  '식당',
#  '카레',
#  '냄새',
#  '진동',
#  '까닭',
#  '루이비통',
#  '롯데',
#  '맞불',
#  '작전',
#  '인기',
#  '고객',
#  '연비',
#  '등장',
#  '요타',
#  '신모',
#  '삼성',
#  '상생',
#  '실천',
#  '안철수연구소',
#  '네트워크',
#  '통합',
#  '보안',
#  '장비',
#  '트러스',
#  '가드',
#  '적용',
#  '기술',
#  '단말',
#  '장치',
#  '상기',
#  '단말',
#  '장치',
#  '악성',
#  '코드',
#  '방지',
#  '방법',
#  '국내',
#  '특허',
#  '획득',
#  '발표',
#  '이번',
#  '기술',
#  '네트워크',
#  '보안',
#  '장비',
#  '보안',
#  '솔루션',
#  '연동',
#  '악성',
#  '트래픽',
#  '내부',
#  '확산',
#  '방지',
#  '자동',
#  '치료',
#  '기술',
#  '네트워크',
#  '보안',
#  '장비',
#  '트러스',
#  '가드',
#  '악성',
#  '트래픽',
#  '탐지',
#  '제품군',
#  '자동',
#  '악성',
#  '트래픽',
#  '차단',
#  '치료',
#  '안철수',
#  '연구소',
#  '지금',
#  '국내외',
#  '보안',
#  '제품',
#  '유사',
#  '기술',
#  '백신',
#  '설치',
#  '여부',
#  '확인',
#  '설치',
#  '유도',
#  '기술',
#  '악성',
#  '트래픽',
#  '차단',
#  '기술',
#  '악성',
#  '코드',
#  '치료',
#  '기술',
#  '제공',
#  '전방',
#  '보안',
#  '구현',
#  '설명',
#  '김종성',
#  '기자',
#  '한국',
#  '경제',
#  '주요',
#  '뉴스',
#  '도로',
#  '얌체',
#  '끼어들기',
#  '사진',
#  '환각',
#  '상태',
#  '운전',
#  '추돌',
#  '폭행',
#  '아파트',
#  '전셋값',
#  '천만',
#  '이상',
#  '급등',
#  '승리',
#  '흥분',
#  '난입',
#  '골대',
#  '사고',
#  '피해액',
#  '세상',
#  '교통사고',
#  '한국',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '국내',
#  '대표',
#  '소프트웨어',
#  '업체',
#  '도약',
#  '선언',
#  '성장세',
#  '업계',
#  '한글',
#  '컴퓨터',
#  '창립',
#  '주년',
#  '이홍구',
#  '한글',
#  '컴퓨터',
#  '대표',
#  '주년',
#  '기념식',
#  '자리',
#  '한컴',
#  '수식어',
#  '기술력',
#  '보유',
#  '소프트웨어',
#  '기업',
#  '지속',
#  '투자',
#  '글로벌',
#  '시장',
#  '개척',
#  '적극',
#  '국민',
#  '기업',
#  '모자람',
#  '최선',
#  '한컴',
#  '성장세',
#  '자신',
#  '배경',
#  '클라우드',
#  '오피스',
#  '사업',
#  '별도',
#  '소프트웨어',
#  '설치',
#  '문서',
#  '작업',
#  '가능',
#  '한글',
#  '컴퓨터',
#  '클라우드',
#  '오피스',
#  '최근',
#  '독일',
#  '수출',
#  '해외',
#  '시장',
#  '공략',
#  '구름판',
#  '역할',
#  '한글',
#  '컴퓨터',
#  '독일',
#  '전기',
#  '전자',
#  '기업',
#  '지멘스',
#  '계약',
#  '씽크',
#  '프리',
#  '서버',
#  '이터',
#  '솔루션',
#  '지멘스',
#  '공급',
#  '예정',
#  '한컴',
#  '상반기',
#  '모바일',
#  '오피스',
#  '사업',
#  '매출',
#  '부문',
#  '성장세',
#  '한컴',
#  '모회사',
#  '소프트',
#  '포럼',
#  '판교',
#  '사옥',
#  '이전',
#  '추진',
#  '향후',
#  '판교',
#  '둥지',
#  '마련',
#  '계획',
#  '판교',
#  '안철수연구소',
#  '소프트',
#  '넥슨',
#  '국내',
#  '대표',
#  '소프트웨어',
#  '업체',
#  '자리',
#  '향후',
#  '시너지',
#  '효과',
#  '예상',
#  '이외',
#  '한컴',
#  '유아',
#  '절대',
#  '사랑',
#  '뽀로로',
#  '기반',
#  '제작',
#  '수익',
#  '다각',
#  '안철수연구소',
#  '이달',
#  '창업',
#  '사옥',
#  '마련',
#  '창업',
#  '선언',
#  '도약',
#  '김홍선',
#  '안철수연구소',
#  '대표',
#  '안철수',
#  '연구소',
#  '창업',
#  '존경',
#  '글로벌',
#  '소프트웨어',
#  '기업',
#  '비상',
#  '중소',
#  '소프트웨어',
#  '기업',
#  '희망',
#  '모델',
#  '역할',
#  '입주',
#  '천사',
#  '데이',
#  '입주식',
#  '개최',
#  '특별',
#  '의미',
#  '부여',
#  '안철수연구소',
#  '실적',
#  '상승세',
#  '안철수연구소',
#  '최근',
#  '응용',
#  '프로그램',
#  '패치',
#  '장치',
#  '방법',
#  '여개',
#  '특허',
#  '취득',
#  '주가',
#  '이상',
#  '보안',
#  '담당자',
#  '초청',
#  '융합',
#  '보안',
#  '전략',
#  '세미나',
#  '개최',
#  '보안',
#  '업계',
#  '사회',
#  '책임',
#  '적극',
#  '계획',
#  '업계',
#  '관계자',
#  '한컴',
#  '주인',
#  '안철수연구소',
#  '수년',
#  '매출',
#  '정체',
#  '국내',
#  '대표',
#  '소프트웨어',
#  '업체',
#  '역할',
#  '최근',
#  '소프트웨어',
#  '산업',
#  '각계',
#  '각층',
#  '관심',
#  '업체',
#  '성장',
#  '유리',
#  '시기',
#  '철민',
#  '기자',
#  '한국',
#  '아이',
#  '닷컴',
#  '기기',
#  '사만',
#  '이하',
#  '카드',
#  '이젠',
#  '망신',
#  '하나',
#  '견제',
#  '한국',
#  '전함',
#  '나경원',
#  '박원순',
#  '건강',
#  '회복',
#  '한국인',
#  '꼴찌',
#  '소녀',
#  '세계',
#  '포스코',
#  '아이',
#  '씨티',
#  '계약',
#  '관련',
#  '계약',
#  '금액',
#  '정정',
#  '공시',
#  '공시',
#  '강재웅',
#  '기자',
#  '오늘',
#  '핫뉴스',
#  '야심',
#  '신라면',
#  '블랙',
#  '꼬꼬면',
#  '가격',
#  '완전',
#  '군장',
#  '가량',
#  '단대',
#  '오거리',
#  '추격',
#  '영상',
#  '네티즌',
#  '직장',
#  '절반',
#  '회사',
#  '남편',
#  '아내',
#  '동료',
#  '고대',
#  '성추행',
#  '대생',
#  '피해자',
#  '피해',
#  '저작',
#  '파이낸셜',
#  '뉴스',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '서비스',
#  '기업',
#  '포스코',
#  '아이',
#  '씨티',
#  '분기',
#  '실적',
#  '발표',
#  '매출',
#  '영업',
#  '이익',
#  '기록',
#  '전년',
#  '동기',
#  '대비',
#  '매출',
#  '증가',
#  '영업',
#  '이익',
#  '포스코',
#  '포스코',
#  '인도네시아',
#  '제철소',
#  '건설',
#  '해외',
#  '진출',
#  '성과',
#  '가시',
#  '분기',
#  '매출',
#  '증가',
#  '확대',
#  '포스코',
#  '올해',
#  '수주',
#  '목표',
#  '조억',
#  '주액',
#  '조원',
#  '돌파',
#  '조선',
#  '비즈',
#  '뉴스',
#  '건물',
#  '전체',
#  '서울',
#  '복판',
#  '빌딩',
#  '굴욕',
#  '매출',
#  '천억',
#  '메가',
#  '수퍼',
#  '사람',
#  '이게',
#  '굴삭기',
#  '월수입',
#  '부부',
#  '월세',
#  '신세',
#  '와인',
#  '탐욕',
#  '효과',
#  '포스코',
#  '아이',
#  '씨티',
#  '충주',
#  '기업',
#  '도시',
#  '부지',
#  '매입',
#  '데이터',
#  '센터',
#  '구축',
#  '투자',
#  '공시',
#  '자기',
#  '자본',
#  '대비',
#  '규모',
#  '조선',
#  '비즈',
#  '뉴스',
#  '프리미엄',
#  '소문',
#  '주말',
#  '임대',
#  '주택',
#  '싹쓸이',
#  '사람',
#  '소유',
#  '천수답',
#  '한국',
#  '경제',
#  '국내',
#  '큰손',
#  '외인구단',
#  '후퇴',
#  '단독',
#  '주택',
#  '아파트',
#  '세금',
#  '포스코',
#  '아이',
#  '씨티',
#  '분기',
#  '잠정',
#  '영업',
#  '이익',
#  '억만',
#  '전년',
#  '동기',
#  '대비',
#  '흑자',
#  '전환',
#  '공시',
#  '기간',
#  '매출액',
#  '억만',
#  '당기',
#  '순이익',
#  '억만',
#  '흑자',
#  '전환',
#  '기법',
#  '전수',
#  '특급',
#  '주식',
#  '방송',
#  '어디',
#  '손안',
#  '아시아',
#  '경제',
#  '배경환',
#  '기자',
#  '세계',
#  '경제',
#  '아시아',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '포스코',
#  '아이',
#  '규모',
#  '해양',
#  '호텔',
#  '설비',
#  '사업',
#  '수주',
#  '포스코',
#  '아이',
#  '씨티',
#  '올해',
#  '예상',
#  '영업',
#  '이익',
#  '달성',
#  '전망',
#  '공시',
#  '매출액',
#  '조억',
#  '회사',
#  '제조',
#  '사업',
#  '분야',
#  '영역',
#  '확대',
#  '역량',
#  '강화',
#  '패밀리',
#  '동반',
#  '진출',
#  '해외',
#  '시장',
#  '확장',
#  '기대',
#  '설명',
#  '한편',
#  '내년도',
#  '주액',
#  '목표',
#  '조원',
#  '매출액',
#  '조억',
#  '기법',
#  '전수',
#  '특급',
#  '주식',
#  '방송',
#  '어디',
#  '손안',
#  '아시아',
#  '경제',
#  '배경환',
#  '기자',
#  '세계',
#  '경제',
#  '아시아',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '포스코',
#  '아이',
#  '씨티',
#  '분기',
#  '영업',
#  '전년',
#  '흑자',
#  '전환',
#  '포스코',
#  '아이',
#  '규모',
#  '해양',
#  '호텔',
#  '설비',
#  '사업',
#  '수주',
#  '포스코',
#  '아이',
#  '씨티',
#  '투자',
#  '재원',
#  '조달',
#  '유동',
#  '비율',
#  '개선',
#  '경기도',
#  '성남시',
#  '분당구',
#  '토지',
#  '건물',
#  '처분',
#  '결정',
#  '공시',
#  '기법',
#  '특급',
#  '주식',
#  '방송',
#  '고수',
#  '매매',
#  '내역',
#  '실시간',
#  '공개',
#  '수익',
#  '매매',
#  '비법',
#  '제시',
#  '성정',
#  '기자',
#  '세계',
#  '경제',
#  '아시아',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '제일제당',
#  '대표',
#  '이사',
#  '손경식',
#  '이재현',
#  '변경',
#  '삼성',
#  '대표',
#  '이사',
#  '박상진',
#  '변경',
#  '삼성',
#  '주식',
#  '만주',
#  '취득',
#  '결정',
#  '삼성전자',
#  '주식',
#  '만주',
#  '취득',
#  '결정',
#  '한국',
#  '대표',
#  '이사',
#  '단재완',
#  '전명현',
#  '변경',
#  '디엔',
#  '주요',
#  '주주',
#  '포스코',
#  '씨티',
#  '대상',
#  '억만',
#  '규모',
#  '신주인수권',
#  '부사',
#  '발행',
#  '공시',
#  '이날',
#  '청약',
#  '납입',
#  '진행',
#  '스마트',
#  '브리프',
#  '하루',
#  '무료',
#  '데일리',
#  '문자',
#  '시세',
#  '추천',
#  '진단',
#  '상담',
#  '정보',
#  '데일리',
#  '모바일',
#  '실시간',
#  '해외',
#  '지수',
#  '글로벌',
#  '경제',
#  '뉴스',
#  '금융',
#  '정보',
#  '터미널',
#  '데일리',
#  '종합',
#  '경제',
#  '정보',
#  '미디어',
#  '데일리',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '안방',
#  '경제',
#  '뉴스',
#  '재테크',
#  '정보',
#  '데일리',
#  '안준형',
#  '포스코',
#  '아이',
#  '씨티',
#  '포스코',
#  '규모',
#  '광양',
#  '열연',
#  '신설',
#  '사업',
#  '열연',
#  '설비',
#  '공급',
#  '계약',
#  '공시',
#  '이세경',
#  '기자',
#  '계좌',
#  '저작',
#  '파이낸셜',
#  '뉴스',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '핵심',
#  '역량',
#  '교류',
#  '구글',
#  '기술',
#  '활용',
#  '미래형',
#  '경영',
#  '시스템',
#  '구축',
#  '세계',
#  '화상',
#  '회의',
#  '가상',
#  '제철소',
#  '구현',
#  '가능',
#  '쇳물',
#  '용광',
#  '근처',
#  '작업자',
#  '접근',
#  '경고',
#  '가상',
#  '차단',
#  '장치',
#  '위험',
#  '감지',
#  '직원',
#  '안전',
#  '때문',
#  '터키',
#  '공장',
#  '재고',
#  '일본',
#  '납품',
#  '제품',
#  '바다',
#  '지점',
#  '디지털',
#  '지도',
#  '세계',
#  '곳곳',
#  '포스코',
#  '제품',
#  '현황',
#  '표시',
#  '국제',
#  '전화',
#  '이메일',
#  '확인',
#  '마우스',
#  '클릭',
#  '점검',
#  '가능',
#  '포스코',
#  '미래',
#  '스마트',
#  '철강',
#  '회사',
#  '모습',
#  '사무실',
#  '물론',
#  '생산',
#  '현장',
#  '정보',
#  '기술',
#  '플랫폼',
#  '도입',
#  '계획',
#  '실현',
#  '포스코',
#  '작업',
#  '환경',
#  '혁명',
#  '정도',
#  '전통',
#  '굴뚝',
#  '산업',
#  '제조업',
#  '첨단',
#  '정보',
#  '기술',
#  '접목',
#  '혁신',
#  '시도',
#  '포스코',
#  '클라우드',
#  '컴퓨팅',
#  '서비스',
#  '도입',
#  '검토',
#  '지난해',
#  '임원',
#  '구글',
#  '본사',
#  '미국',
#  '실리콘밸리',
#  '관련',
#  '회사',
#  '최종',
#  '대상',
#  '선택',
#  '구글',
#  '슈미트',
#  '구글',
#  '회장',
#  '정준양',
#  '포스코',
#  '회장',
#  '시간',
#  '가량',
#  ...]

# %%
c = Counter(list_text_1) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
print()

# %%
c
# Out:
# Counter({'씨제이': 5,
#          '규모': 961,
#          '유형': 17,
#          '자산': 204,
#          '취득': 253,
#          '공시': 854,
#          '판교': 21,
#          '도시': 72,
#          '특별': 62,
#          '계획': 503,
#          '구역': 7,
#          '중심': 242,
#          '상업': 27,
#          '지내': 1,
#          '신축': 29,
#          '예정': 473,
#          '건물': 24,
#          '목적': 68,
#          '제자': 31,
#          '처분': 52,
#          '흡수': 26,
#          '합병': 125,
#          '미디어': 564,
#          '방송': 496,
#          '사옥': 36,
#          '복합': 34,
#          '사업': 1401,
#          '컨소시엄': 17,
#          '알파': 25,
#          '시티': 17,
#          '출자': 61,
#          '해당': 276,
#          '필요': 279,
#          '매입': 97,
#          '상대방': 16,
#          '확정': 109,
#          '대로': 13,
#          '조선': 216,
#          '비즈': 104,
#          '뉴스': 1712,
#          '삼성': 481,
#          '전자': 675,
#          '업계': 349,
#          '리더': 16,
#          '휴가': 13,
#          '이유': 241,
#          '한국': 1768,
#          '증시': 296,
#          '상장': 901,
#          '중국': 728,
#          '기업': 2235,
#          '섰다': 1,
#          '건설사': 29,
#          '저작': 928,
#          '등록': 24,
#          '남양유업': 7,
#          '돌풍': 33,
#          '조억': 191,
#          '커피': 43,
#          '믹스': 31,
#          '시장': 2991,
#          '요동': 2,
#          '코스닥': 1067,
#          '소폭': 63,
#          '하락': 606,
#          '출발': 43,
#          '예상': 1248,
#          '시가총액': 188,
#          '상위': 228,
#          '종목': 1724,
#          '매도': 201,
#          '우위': 91,
#          '다수': 49,
#          '판단': 376,
#          '에스에프': 44,
#          '백스': 177,
#          '산하이': 102,
#          '메탈': 135,
#          '매수세': 63,
#          '유입': 57,
#          '업종': 481,
#          '기계': 159,
#          '장비': 750,
#          '인터넷': 176,
#          '금융': 821,
#          '금속': 81,
#          '상대': 178,
#          '강세': 257,
#          '삼성전자': 618,
#          '식당': 8,
#          '카레': 1,
#          '냄새': 11,
#          '진동': 45,
#          '까닭': 9,
#          '루이비통': 7,
#          '롯데': 98,
#          '맞불': 3,
#          '작전': 12,
#          '인기': 204,
#          '고객': 465,
#          '연비': 23,
#          '등장': 132,
#          '요타': 2,
#          '신모': 1,
#          '상생': 20,
#          '실천': 12,
#          '안철수연구소': 24,
#          '네트워크': 100,
#          '통합': 47,
#          '보안': 27,
#          '트러스': 8,
#          '가드': 3,
#          '적용': 238,
#          '기술': 909,
#          '단말': 2,
#          '장치': 164,
#          '상기': 5,
#          '악성': 10,
#          '코드': 26,
#          '방지': 32,
#          '방법': 101,
#          '국내': 1086,
#          '특허': 264,
#          '획득': 52,
#          '발표': 359,
#          '이번': 749,
#          '솔루션': 150,
#          '연동': 14,
#          '트래픽': 13,
#          '내부': 53,
#          '확산': 82,
#          '자동': 114,
#          '치료': 79,
#          '탐지': 3,
#          '제품군': 27,
#          '차단': 30,
#          '안철수': 62,
#          '연구소': 52,
#          '지금': 81,
#          '국내외': 98,
#          '제품': 1136,
#          '유사': 42,
#          '백신': 142,
#          '설치': 45,
#          '여부': 80,
#          '확인': 188,
#          '유도': 20,
#          '제공': 336,
#          '전방': 129,
#          '구현': 59,
#          '설명': 672,
#          '김종성': 16,
#          '기자': 1705,
#          '경제': 2009,
#          '주요': 389,
#          '도로': 21,
#          '얌체': 1,
#          '끼어들기': 1,
#          '사진': 167,
#          '환각': 2,
#          '상태': 239,
#          '운전': 21,
#          '추돌': 1,
#          '폭행': 51,
#          '아파트': 99,
#          '전셋값': 4,
#          '천만': 102,
#          '이상': 753,
#          '급등': 237,
#          '승리': 10,
#          '흥분': 3,
#          '난입': 2,
#          '골대': 1,
#          '사고': 46,
#          '피해액': 3,
#          '세상': 114,
#          '교통사고': 6,
#          '무단': 1681,
#          '전재': 1673,
#          '배포': 1761,
#          '금지': 1781,
#          '대표': 854,
#          '소프트웨어': 136,
#          '업체': 1748,
#          '도약': 39,
#          '선언': 12,
#          '성장세': 292,
#          '한글': 33,
#          '컴퓨터': 59,
#          '창립': 30,
#          '주년': 15,
#          '이홍구': 1,
#          '기념식': 15,
#          '자리': 102,
#          '한컴': 8,
#          '수식어': 1,
#          '기술력': 203,
#          '보유': 593,
#          '지속': 618,
#          '투자': 3520,
#          '글로벌': 677,
#          '개척': 41,
#          '적극': 129,
#          '국민': 261,
#          '모자람': 1,
#          '최선': 20,
#          '자신': 50,
#          '배경': 36,
#          '클라우드': 17,
#          '오피스': 21,
#          '별도': 72,
#          '문서': 15,
#          '작업': 89,
#          '가능': 850,
#          '최근': 1220,
#          '독일': 42,
#          '수출': 259,
#          '해외': 547,
#          '공략': 95,
#          '구름판': 1,
#          '역할': 93,
#          '전기': 151,
#          '지멘스': 3,
#          '계약': 680,
#          '씽크': 92,
#          '프리': 15,
#          '서버': 21,
#          '이터': 2,
#          '공급': 790,
#          '상반기': 298,
#          '모바일': 708,
#          '매출': 2064,
#          '부문': 435,
#          '모회사': 17,
#          '소프트': 112,
#          '포럼': 21,
#          '이전': 106,
#          '추진': 211,
#          '향후': 353,
#          '둥지': 3,
#          '마련': 127,
#          '넥슨': 25,
#          '시너지': 63,
#          '효과': 370,
#          '이외': 52,
#          '유아': 75,
#          '절대': 32,
#          '사랑': 23,
#          '뽀로로': 13,
#          '기반': 217,
#          '제작': 168,
#          '수익': 1273,
#          '다각': 19,
#          '이달': 117,
#          '창업': 148,
#          '김홍선': 1,
#          '존경': 5,
#          '비상': 15,
#          '중소': 59,
#          '희망': 118,
#          '모델': 219,
#          '입주': 25,
#          '천사': 4,
#          '데이': 8,
#          '입주식': 1,
#          '개최': 82,
#          '의미': 93,
#          '부여': 29,
#          '실적': 2067,
#          '상승세': 136,
#          '응용': 29,
#          '프로그램': 87,
#          '패치': 3,
#          '여개': 38,
#          '주가': 2263,
#          '담당자': 14,
#          '초청': 8,
#          '융합': 33,
#          '전략': 320,
#          '세미나': 23,
#          '사회': 86,
#          '책임': 41,
#          '관계자': 460,
#          '주인': 56,
#          '수년': 16,
#          '정체': 43,
#          '산업': 732,
#          '각계': 2,
#          '각층': 1,
#          '관심': 340,
#          '성장': 1788,
#          '유리': 154,
#          '시기': 63,
#          '철민': 2,
#          '아이': 438,
#          '닷컴': 417,
#          '기기': 263,
#          '사만': 1,
#          '이하': 48,
#          '카드': 156,
#          '이젠': 18,
#          '망신': 8,
#          '하나': 415,
#          '견제': 10,
#          '전함': 1,
#          '나경원': 6,
#          '박원순': 28,
#          '건강': 88,
#          '회복': 176,
#          '한국인': 16,
#          '꼴찌': 3,
#          '소녀': 53,
#          '세계': 918,
#          '포스코': 267,
#          '씨티': 40,
#          '관련': 777,
#          '금액': 192,
#          '정정': 8,
#          '강재웅': 7,
#          '오늘': 372,
#          '핫뉴스': 139,
#          '야심': 6,
#          '신라면': 9,
#          '블랙': 35,
#          '꼬꼬면': 36,
#          '가격': 432,
#          '완전': 34,
#          '군장': 1,
#          '가량': 168,
#          '단대': 1,
#          '오거리': 2,
#          '추격': 7,
#          '영상': 117,
#          '네티즌': 33,
#          '직장': 28,
#          '절반': 74,
#          '회사': 1065,
#          '남편': 58,
#          '아내': 44,
#          '동료': 3,
#          '고대': 9,
#          '성추행': 11,
#          '대생': 16,
#          '피해자': 22,
#          '피해': 32,
#          '파이낸셜': 243,
#          '서비스': 663,
#          '분기': 2669,
#          '영업': 2172,
#          '이익': 2113,
#          '기록': 1639,
#          '전년': 889,
#          '동기': 458,
#          '대비': 1795,
#          '증가': 2007,
#          '인도네시아': 22,
#          '제철소': 10,
#          '건설': 252,
#          '진출': 386,
#          '성과': 166,
#          '가시': 75,
#          '확대': 882,
#          '올해': 1564,
#          '수주': 389,
#          '목표': 1137,
#          '주액': 9,
#          '조원': 129,
#          '돌파': 96,
#          '전체': 477,
#          '서울': 504,
#          '복판': 5,
#          '빌딩': 37,
#          '굴욕': 46,
#          '천억': 69,
#          '메가': 81,
#          '수퍼': 2,
#          '사람': 142,
#          '이게': 20,
#          '굴삭기': 1,
#          '월수입': 1,
#          '부부': 40,
#          '월세': 8,
#          '신세': 2,
#          '와인': 3,
#          '탐욕': 2,
#          '충주': 1,
#          '부지': 32,
#          '데이터': 106,
#          '센터': 178,
#          '구축': 164,
#          '자기': 84,
#          '자본': 170,
#          '프리미엄': 102,
#          '소문': 26,
#          '주말': 18,
#          '임대': 11,
#          '주택': 91,
#          '싹쓸이': 10,
#          '소유': 21,
#          '천수답': 1,
#          '큰손': 13,
#          '외인구단': 1,
#          '후퇴': 6,
#          '단독': 57,
#          '세금': 20,
#          '잠정': 91,
#          '억만': 1032,
#          '흑자': 260,
#          '전환': 424,
#          '기간': 569,
#          '매출액': 1533,
#          '당기': 397,
#          '순이익': 598,
#          '기법': 75,
#          '전수': 23,
#          '특급': 39,
#          '주식': 742,
#          '어디': 218,
#          '손안': 116,
#          '아시아': 381,
#          '배경환': 5,
#          '해양': 77,
#          '호텔': 76,
#          '설비': 311,
#          '달성': 336,
#          '전망': 1539,
#          '제조': 431,
#          '분야': 310,
#          '영역': 114,
#          '역량': 71,
#          '강화': 300,
#          '패밀리': 39,
#          '동반': 91,
#          '확장': 78,
#          '기대': 927,
#          '한편': 220,
#          '내년도': 12,
#          '재원': 3,
#          '조달': 104,
#          '유동': 55,
#          '비율': 232,
#          '개선': 804,
#          '경기도': 24,
#          '성남시': 3,
#          '분당구': 1,
#          '토지': 33,
#          '결정': 298,
#          '고수': 44,
#          '매매': 351,
#          '내역': 65,
#          '실시간': 326,
#          '공개': 338,
#          '비법': 27,
#          '제시': 582,
#          '성정': 2,
#          '제일제당': 5,
#          '이사': 197,
#          '손경식': 1,
#          '이재현': 2,
#          '변경': 142,
#          '박상진': 3,
#          '만주': 207,
#          '단재완': 2,
#          '전명현': 1,
#          '디엔': 1,
#          '주주': 256,
#          '대상': 355,
#          '신주인수권': 51,
#          '부사': 41,
#          '발행': 180,
#          '이날': 338,
#          '청약': 183,
#          '납입': 19,
#          '진행': 509,
#          '스마트': 399,
#          '브리프': 34,
#          '하루': 161,
#          '무료': 216,
#          '데일리': 947,
#          '문자': 99,
#          '시세': 51,
#          '추천': 348,
#          '진단': 296,
#          '상담': 175,
#          '정보': 948,
#          '지수': 350,
#          '터미널': 61,
#          '종합': 508,
#          '안방': 55,
#          '재테크': 144,
#          '안준형': 6,
#          '광양': 7,
#          '열연': 2,
#          '신설': 31,
#          '이세경': 1,
#          '계좌': 92,
#          '핵심': 278,
#          '교류': 13,
#          '구글': 53,
#          '활용': 187,
#          '미래형': 2,
#          '경영': 261,
#          '시스템': 421,
#          '화상': 16,
#          '회의': 28,
#          '가상': 24,
#          '쇳물': 2,
#          '용광': 1,
#          '근처': 9,
#          '작업자': 4,
#          '접근': 53,
#          '경고': 20,
#          '위험': 98,
#          '감지': 17,
#          '직원': 113,
#          '안전': 118,
#          '때문': 797,
#          '터키': 7,
#          '공장': 367,
#          '재고': 51,
#          '일본': 381,
#          '납품': 193,
#          '바다': 27,
#          '지점': 89,
#          '디지털': 358,
#          '지도': 32,
#          '곳곳': 5,
#          '현황': 21,
#          '표시': 24,
#          '국제': 88,
#          '전화': 80,
#          '이메일': 4,
#          '마우스': 58,
#          '클릭': 24,
#          '점검': 31,
#          '미래': 347,
#          '철강': 60,
#          '모습': 200,
#          '사무실': 24,
#          '물론': 10,
#          '생산': 872,
#          '현장': 63,
#          '플랫폼': 85,
#          '도입': 113,
#          '실현': 76,
#          '환경': 147,
#          '혁명': 11,
#          '정도': 318,
#          '전통': 24,
#          '굴뚝': 2,
#          '제조업': 20,
#          '첨단': 46,
#          '접목': 11,
#          '혁신': 96,
#          '시도': 42,
#          '컴퓨팅': 2,
#          '검토': 55,
#          '지난해': 1095,
#          '임원': 46,
#          '본사': 103,
#          '미국': 690,
#          '실리콘밸리': 5,
#          '최종': 70,
#          '선택': 73,
#          '슈미트': 2,
#          '회장': 323,
#          '정준양': 2,
#          '시간': 181,
#          '논의': 16,
#          '속도': 81,
#          '스피드': 12,
#          '개방': 13,
#          '중시': 4,
#          '협력': 199,
#          '완성': 29,
#          '시대': 142,
#          '전환점': 4,
#          '구애': 1,
#          '기획': 60,
#          '창의': 9,
#          '문화': 75,
#          '방식': 203,
#          '협업': 34,
#          '부분': 157,
#          '귀띔': 7,
#          '보름': 3,
#          '양사': 26,
#          '지식': 66,
#          '노동자': 1,
#          '패러다임': 8,
#          '가치': 276,
#          '내용': 109,
#          '양해': 14,
#          '각서': 13,
#          '장기': 237,
#          '위원회': 81,
#          '구성': 100,
#          '구체': 31,
#          '공동': 130,
#          '연구': 218,
#          '차례': 67,
#          '워크숍': 1,
#          '사이': 74,
#          '인력': 75,
#          '동아시아': 8,
#          '관리': 213,
#          '계열사': 128,
#          '소통': 30,
#          '외부': 30,
#          '저장': 21,
#          '우려': 191,
#          '각지': 6,
#          '임직원': 45,
#          '공간': 31,
#          '개인': 252,
#          '스마트폰': 611,
#          '태블릿': 298,
#          '피시': 5,
#          '자유': 28,
#          '음성': 12,
#          '채팅': 36,
#          '번역': 3,
#          '기능': 153,
#          '지원': 252,
#          '검색': 46,
#          '차원': 54,
#          '다양': 111,
#          '장애': 17,
#          '발생': 233,
#          '시뮬레이션': 8,
#          '파악': 66,
#          '운송': 28,
#          '과정': 111,
#          '추적': 8,
#          '바탕': 129,
#          '기존': 545,
#          '전사': 15,
#          '자원': 48,
#          '포스': 114,
#          '피아': 28,
#          '발전': 176,
#          '황예': 2,
#          '공식': 189,
#          '구독': 110,
#          '신청': 164,
#          '한겨레': 7,
#          '신문사': 9,
#          '온라인': 430,
#          '신문': 570,
#          '협회': 252,
#          '이용': 452,
#          '규칙': 183,
#          '행사': 356,
#          '스트립': 6,
#          '절단': 51,
#          '용접': 24,
#          '레이저': 140,
#          '개발': 1043,
#          '절약': 6,
#          '유출': 40,
#          '이제': 30,
#          '국산': 55,
#          '성공': 643,
#          '고가': 83,
#          '개월': 383,
#          '판매': 644,
#          '냉연': 5,
#          '공정': 377,
#          '선행': 13,
#          '코일': 3,
#          '뒷부분': 1,
#          '후행': 1,
#          '앞부분': 1,
#          '전량': 54,
#          '구매': 111,
#          '소모품': 13,
#          '절감': 77,
#          '품질': 77,
#          '균일화': 3,
#          '보탬': 4,
#          '수입': 105,
#          '마모': 1,
#          '직각도': 1,
#          '확보': 368,
#          '어려움': 43,
#          '사용': 300,
#          '절단면': 2,
#          '정밀': 90,
#          '교체': 57,
#          '국산화': 60,
#          '성분': 16,
#          '제작사': 25,
#          '철강재': 1,
#          '제조사': 32,
#          '사전': 33,
#          '여지': 13,
#          '수십': 8,
#          '강종': 2,
#          '측정': 18,
#          '강판': 4,
#          '구멍': 6,
#          '디텍터': 1,
#          '본격': 502,
#          '하이닉스': 130,
#          '반도체': 699,
#          '하이오': 1,
#          '피스': 6,
#          '업무': 48,
#          '접속': 18,
#          '일과': 2,
#          '시작': 443,
#          '사내': 22,
#          '메일': 11,
#          '공지': 2,
#          '사항': 94,
#          '각종': 53,
#          '공유': 59,
#          '책상': 2,
#          '종이': 25,
#          '일반': 139,
#          '휴대폰': 233,
#          '대리점': 34,
#          '영화관': 10,
#          '교환': 10,
#          '페이퍼리스': 3,
#          '출력': 14,
#          '기밀': 2,
#          '고지서': 1,
#          '걱정': 18,
#          '본인': 28,
#          '조회': 88,
#          '사무': 12,
#          '차지': 237,
#          '나무': 26,
#          '친환경': 31,
#          '조성': 58,
#          '최대': 594,
#          '동시': 104,
#          '생성': 7,
#          '유통': 151,
#          '폐기': 3,
#          '이력': 2,
#          '투명': 41,
#          '자사': 49,
#          '운영': 154,
#          '실행': 12,
#          '디스플레이': 394,
#          '동국제강': 9,
#          '텔레콤': 75,
#          '병원': 99,
#          '가입': 27,
#          '월드': 36,
#          '개설': 9,
#          '신규': 772,
#          '작성': 77,
#          '신청서': 8,
#          '전송': 11,
#          '보호': 123,
#          '장점': 39,
#          '통신': 397,
#          '롯데시네마': 3,
#          '구관': 1,
#          '영화': 262,
#          '포스터': 10,
#          '티켓': 5,
#          '안내': 42,
#          '대구': 24,
#          '하관': 1,
#          '청량리': 4,
#          '일산': 9,
#          '페스': 2,
#          '타관': 1,
#          '가천': 2,
#          '대길': 2,
#          '체결': 411,
#          '처방': 15,
#          '전달': 34,
#          '환자': 61,
#          '의료': 157,
#          '진료': 2,
#          '우편': 2,
#          '신용': 100,
#          '요금': 22,
#          '청구서': 11,
#          '이동': 90,
#          '신한': 202,
#          '국영': 6,
#          '항공사': 9,
#          '차이': 86,
#          '요즘': 25,
#          '킹크': 2,
#          '전문점': 11,
#          '폐업': 2,
#          '속출': 8,
#          '아우디': 9,
#          '그녀': 63,
#          '비결': 50,
#          '사활': 4,
#          '망고': 11,
#          '애플': 207,
#          '소송': 58,
#          '잡스': 12,
#          '오른팔': 3,
#          '복수': 11,
#          '실패': 33,
#          '강원도': 16,
#          '속초시': 6,
#          '대포항': 22,
#          '랜드마크': 11,
#          '요트': 10,
#          '승마': 8,
#          '골프': 182,
#          '스키': 4,
#          '스파': 8,
#          '레저': 24,
#          '휴양': 8,
#          '자금': 361,
#          '투자자': 414,
#          '발길': 4,
#          '호피': 2,
#          '스텔': 2,
#          '팔라': 4,
#          '자노': 21,
#          '강원': 8,
#          '개념': 36,
#          '분양': 110,
#          '스카이라운지': 2,
#          '일출': 4,
#          '감상': 6,
#          '룸서비스': 2,
#          '아침': 19,
#          '해결': 34,
#          '가족': 32,
#          '활어': 2,
#          '횟집': 2,
#          '점심': 5,
#          '식사': 7,
#          '각자': 7,
#          '취향': 10,
#          '레스토랑': 6,
#          '저녁': 4,
#          '방파제': 6,
#          '산책': 3,
#          '동남': 6,
#          '해안': 3,
#          '농림': 5,
#          '수산': 7,
#          '식품': 110,
#          '초시': 8,
#          '동해안': 5,
#          '최초': 198,
#          '매립': 18,
#          '최신': 47,
#          '공법': 23,
#          '시공': 16,
#          '입구': 3,
#          '최고': 408,
#          '개동': 7,
#          '고급': 64,
#          '숙박': 8,
#          '시설': 114,
#          '설악산': 2,
#          '동해': 5,
#          '영구': 4,
#          '조망권': 2,
#          '천혜': 2,
#          '자연': 34,
#          '경관': 6,
#          '리조트': 5,
#          '조합': 77,
#          '관광': 25,
#          '주거': 13,
#          '비즈니스': 33,
#          '총망라': 2,
#          '담당': 55,
#          '지방': 34,
#          '지역': 178,
#          '육상': 6,
#          '스포츠': 70,
#          '경기': 231,
#          '부산': 73,
#          '대전': 33,
#          '제외': 130,
#          '초고층': 4,
#          '중상': 4,
#          '레포츠': 4,
#          '투입': 47,
#          '별장': 21,
#          '장만': 5,
#          '소식': 132,
#          '컨벤션': 4,
#          '연수원': 5,
#          '부족': 74,
#          '기회': 137,
#          '속초': 6,
#          '동력': 110,
#          '프로젝트': 85,
#          '지구': 35,
#          '포함': 210,
#          '대단위': 2,
#          '단지': 22,
#          '건립': 20,
#          '특징': 116,
#          '중앙': 38,
#          '정부': 183,
#          '자치': 4,
#          '단체': 27,
#          '민간': 34,
#          '지자체': 7,
#          '어항': 6,
#          '공존': 47,
#          '월일': 218,
#          '착공': 14,
#          '외곽': 3,
#          '방파': 2,
#          '호안': 2,
#          '접안': 2,
#          '물양장': 2,
#          '어선': 7,
#          '수리소': 2,
#          '축조': 2,
#          '공사': 71,
#          '휴게': 4,
#          '인근': 22,
#          '수역': 3,
#          '계류': 2,
#          '보관': 10,
#          '클럽': 43,
#          '하우스': 24,
#          '수리': 7,
#          '세정': 7,
#          '주차장': 10,
#          '대포': 4,
#          '외옹치항': 2,
#          '편의': 24,
#          '계절': 35,
#          '관광지': 2,
#          '국비': 3,
#          '지방비': 2,
#          '심층수': 2,
#          '테라': 14,
#          '랜드': 12,
#          '광장': 8,
#          '객실': 6,
#          '여실': 2,
#          '분과': 8,
#          '담보': 26,
#          '계약자': 6,
#          '파격': 75,
#          '조건': 29,
#          '개별': 65,
#          '등기': 5,
#          '회원': 23,
#          '양도': 16,
#          '예금': 18,
#          '증서': 11,
#          '보장': 18,
#          '생보': 3,
#          '부동산': 84,
#          '신탁': 25,
#          '향서': 5,
#          '침체': 58,
#          '일로': 2,
#          '중단': 34,
#          '문제': 112,
#          '노측': 2,
#          '논현동': 2,
#          '학동역': 2,
#          '채용생': 2,
#          '허남석': 2,
#          '사장': 217,
#          '백영환': 2,
#          '참석': 54,
#          '가운데': 292,
#          '개관식': 2,
#          '부자': 70,
#          '친구': 106,
#          '황준호': 14,
#          '비하': 7,
#          '논란': 130,
#          '조혜련': 5,
#          '마디': 7,
#          '아이폰': 170,
#          '화면': 32,
#          '디자인': 49,
#          '충격': 263,
#          '강용석': 17,
#          '의원': 12,
#          '정남': 10,
#          '고소': 11,
#          '긴장': 10,
#          '농심': 19,
#          '야심작': 11,
#          '앵커': 31,
#          '결국': 163,
#          '우리나라': 18,
#          '진원지': 1,
#          '동서': 36,
#          '남해안': 1,
#          '높이': 4,
#          ...})

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250,background_color='white')
gen = wc.generate_from_frequencies(c)
plt.figure(figsize=(6,8))

plt.imshow(gen)
wc.to_file('정상_워드클라우드.png')
