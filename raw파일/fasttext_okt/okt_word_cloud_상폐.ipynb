# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np
import re
from eunjeon import Mecab

# %%
상폐기업 = pd.read_csv('./data/상폐기업뉴스.csv')
data=상폐기업

# %%
data[:5]
# Out:
#        기업                기사발행일                              기사제목  \
# 0  네이쳐글로벌  2010.10.01. 오전 9:23  [특징주] 네이쳐글로벌 상한가…"전 대표 횡령 확인 안돼"
# 1  네이쳐글로벌  2010.10.02. 오전 2:02          [코스닥 기업공시] (1일) 네이쳐글로벌 등
# 2  네이쳐글로벌  2010.09.28. 오후 4:29         네이쳐글로벌, 네비스탁측이 74만여주 장내매도
# 3  네이쳐글로벌  2010.09.16. 오전 9:23       [특징주] 네이쳐글로벌, 투자경고 지정 이후 약세
# 4  네이쳐글로벌  2010.09.14. 오후 4:21     네비스탁외 51인, 네이쳐글로벌 지분 1.26% 줄어
#
#                                               뉴스기사본문
# 0  비메모리 반도체 업체인 네이쳐글로벌이 전 대표 횡령 혐의에 대해 확인된 바 없다고 ...
# 1  ▲네이쳐글로벌=전 대표이사의 횡령,배임 및 가장납입이 확인되지 않음.\n\n▲세동=...
# 2  [이데일리 안재만 기자] 네비스탁은 특별관계자로 포함된 개인투자자들이 네이쳐글로벌(...
# 3  네이쳐글로벌이 투자경고 지정 소식에 이어 전환사채(CB) 물량 상장에 따른 수급 불...
# 4  [이데일리 유용무 기자] 네비스탁외 51인은 14일 신규 소액주주 의결권 규합 및 ...

# %%
제거할기사제목 = ['증시 일정', '증시일정', '장마감후', '장 마감 후', '장마감공시', '증시 캘린더', '재송', '투자정보', \
    '코스닥 기업공시', '장중 주요', '코스닥 3분기 결산', '주요 뉴스 및 공시', '기업공시',' 기업 공시', '장 종료 후', \
        '특징주A/S', '주요 정보', '오전 공시', '투자정보', '기업 공시', '오늘의 메모', '재테크 캘린더', '추천주 정리', '희망복원 주식클리닉', \
        '\d{1,2}월 \d{1,2}일', '오늘의 주요 공시', '코스닥 공시', '코스닥 메모', '대박 공모주', '<표>', '오늘의 리포트', \
        '공략주', '주식상담소', '주식왕 따라잡기', '주식컨설팅', '\d{4} 증시', '춤추는 테마주', '개장시황', \
        '폭등신호 터진', '대폭등', '매드머니', '주담과 Q&A', '굿바이 \d{4}', '지금 당장 사라', '폭등주', \
        '\d{4}%', '김정일 사망', '종목대탐험', '종목신호등', 'VIP CLUB', '수급유망주', '기상도', '중소형주', \
        '국민주식고충처리반', '유망주', '머니Q', '시초가잡아라', '기관 Q&A', '부동산에 투자하려면', '베스트애널리스트', \
        '코스닥협회장 취임', '코스닥협회', '부동산에 투자하는 방법', '국가품질 경영대회', '증시일정', '머니Q', '추천종목', '티타임 공략주', \
        '수급유망주', '종목배틀', '\d{4} 증시 결산', '기업설명회', '종목신호등', 'VIP CLUB 추천주', '내일장 공략주 10선', '주간컨센서스동향', \
        '주담과 Q&A', '조회공시', '주가급등 사유', '관련株들', '게임株', '이시각 Up&Down', '장내 매도', '[인사]', '증시기상도', \
        '[재송]', '마감시황', '주식부자 속출', '교육주', '티타임 공략주', '\d{1,2}일 증권사 추천종목', '기업IR소식', '[승부주]']
# 제거제목리스트=[]
제거제목리스트 = '|'.join(제거할기사제목)
data_unique = data.drop_duplicates(['뉴스기사본문'])
data_result = data_unique[~data_unique['기사제목'].str.contains(제거제목리스트, na=False, case=False)]
#data_result.to_csv('dd.csv')
pattern1 = r'\([^)]*\)'
#pattern2 = r'\[[^)]*\]'
pattern2 = r"\[([^]]+)\]"



# data_unique['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_unique['뉴스기사본문']]
# data_unique['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_unique['뉴스기사본문전처리']]
# data_unique
# data_unique.to_csv('dd.csv', index=None)





data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]
data_result
data_result.to_csv('dd.csv', index=None)
# Out:
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern1, '', s) for s in data_result['뉴스기사본문']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub(pattern2, '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[^/^$|\s+/가-힣\.]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:39: FutureWarning: Possible nested set at position 1
#   data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('[[ \s]{2,}\.{2,}]', '', s) for s in data_result['뉴스기사본문전처리']]
# C:\Users\jangd\AppData\Local\Temp\ipykernel_25780\696962634.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result['뉴스기사본문전처리'] = [re.sub('\n', '', s) for s in data_result['뉴스기사본문전처리']]

# %%
train_data = pd.read_csv('./dd.csv')

# %%
# 불용어 정의
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 형태소 분석기 mecab를 사용한 토큰화 작업 (다소 시간 소요)

mecab = Mecab()
tokenized_data = []
output=[]
for sentence in train_data['뉴스기사본문전처리']:
    temp_X = mecab.nouns(sentence)  # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords]  # 불용어 제거

    tokenized_data.append(temp_X)

# %% [markdown]
# 한글자 제거

# %%
remove_one_word=[]
for j in range(len(tokenized_data)):
    a=[x for x in tokenized_data[j] if len(x)>1]
    remove_one_word.append(a)

# %%
remove_one_word
len(remove_one_word)
list_text_1=sum(remove_one_word, [])

# %%
list_text_1
# Out:
# ['글로벌',
#  '반기',
#  '검토',
#  '의견',
#  '의견',
#  '거절',
#  '관리',
#  '종목',
#  '지정',
#  '사유',
#  '발생',
#  '공시',
#  '한국',
#  '거래소',
#  '글로벌',
#  '주권',
#  '매매',
#  '거래',
#  '정지',
#  '공시',
#  '한경',
#  '닷컴',
#  '최성남',
#  '기자',
#  '오늘',
#  '추천',
#  '종목',
#  '기습',
#  '극비',
#  '세력',
#  '밸류',
#  '무료',
#  '체험',
#  '당첨',
#  '이벤트',
#  '성공',
#  '습관',
#  '한경',
#  '닷컴',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '한국',
#  '온라인',
#  '신문',
#  '협회',
#  '디지털',
#  '뉴스',
#  '이용',
#  '규칙',
#  '저작',
#  '행사',
#  '글로벌',
#  '신용',
#  '등급',
#  '기존',
#  '하향',
#  '조정',
#  '신정',
#  '평가',
#  '정평',
#  '금융',
#  '기관',
#  '신인',
#  '저하',
#  '주력',
#  '사업',
#  '약화',
#  '수익',
#  '기반',
#  '대폭',
#  '축소',
#  '신규',
#  '사업',
#  '소송',
#  '관련',
#  '우발',
#  '채무',
#  '현실',
#  '가능',
#  '고려',
#  '이번',
#  '등급',
#  '하향',
#  '배경',
#  '설명',
#  '정평',
#  '향후',
#  '신용',
#  '등급',
#  '의미',
#  '등급',
#  '전망',
#  '부정',
#  '평가',
#  '저조',
#  '현금',
#  '흐름',
#  '지속',
#  '예상',
#  '가운데',
#  '신규',
#  '사업',
#  '전개',
#  '투자',
#  '부담',
#  '가능',
#  '고려',
#  '데일리',
#  '문자',
#  '시세',
#  '추천',
#  '진단',
#  '상담',
#  '정보',
#  '데일리',
#  '모바일',
#  '실시간',
#  '해외',
#  '지수',
#  '글로벌',
#  '경제',
#  '뉴스',
#  '금융',
#  '정보',
#  '터미널',
#  '데일리',
#  '종합',
#  '경제',
#  '정보',
#  '미디어',
#  '데일리',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '안방',
#  '경제',
#  '뉴스',
#  '재테크',
#  '정보',
#  '데일리',
#  '이태호',
#  '글로벌',
#  '감자',
#  '결의',
#  '공시',
#  '감자',
#  '주주',
#  '총회',
#  '다음',
#  '감자',
#  '기준일',
#  '월일',
#  '감자',
#  '사유',
#  '재무',
#  '구조',
#  '개선',
#  '글로벌',
#  '감자',
#  '월일',
#  '최대',
#  '주주',
#  '메이드',
#  '밤비',
#  '대상',
#  '규모',
#  '유상',
#  '증자',
#  '실시',
#  '메이드',
#  '유상',
#  '증자',
#  '참여',
#  '만주',
#  '보유',
#  '최대',
#  '주주',
#  '데일리',
#  '문자',
#  '시세',
#  '추천',
#  '진단',
#  '상담',
#  '정보',
#  '데일리',
#  '모바일',
#  '실시간',
#  '해외',
#  '지수',
#  '글로벌',
#  '경제',
#  '뉴스',
#  '금융',
#  '정보',
#  '터미널',
#  '데일리',
#  '종합',
#  '경제',
#  '정보',
#  '미디어',
#  '데일리',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '안방',
#  '경제',
#  '뉴스',
#  '재테크',
#  '정보',
#  '데일리',
#  '안재만',
#  '글로벌',
#  '거래일',
#  '연속',
#  '하한가',
#  '기록',
#  '주가',
#  '위협',
#  '글로벌',
#  '오전',
#  '시작',
#  '가격',
#  '제한',
#  '하한가',
#  '가격',
#  '오전',
#  '시분',
#  '거래량',
#  '하한가',
#  '잔량',
#  '현재',
#  '거래량',
#  '여주',
#  '글로벌',
#  '하한가',
#  '관련',
#  '글로벌',
#  '개인',
#  '계좌',
#  '만주',
#  '투자주',
#  '종목',
#  '지정',
#  '만주',
#  '글로벌',
#  '전체',
#  '주식',
#  '수의',
#  '해당',
#  '거래',
#  '글로벌',
#  '투자주',
#  '종목',
#  '지정',
#  '개인',
#  '계좌',
#  '만주',
#  '매도',
#  '물량',
#  '결과',
#  '현상',
#  '이날',
#  '오전',
#  '시분',
#  '증권',
#  '창구',
#  '매도',
#  '물량',
#  '만주',
#  '규정',
#  '당일',
#  '정규',
#  '시장',
#  '특정',
#  '계좌',
#  '매수',
#  '수량',
#  '상장주',
#  '식수',
#  '대비',
#  '이상',
#  '당일',
#  '종가',
#  '전날',
#  '종가',
#  '이상',
#  '상승',
#  '투자주',
#  '종목',
#  '지정',
#  '글로벌',
#  '규모',
#  '생수',
#  '회사',
#  '자산',
#  '양수',
#  '방식',
#  '인수',
#  '추진',
#  '언론',
#  '대표',
#  '이사',
#  '상대',
#  '신주',
#  '발행',
#  '무효',
#  '소송',
#  '제기',
#  '취하',
#  '보도',
#  '주가',
#  '역행',
#  '모습',
#  '회사',
#  '입장',
#  '정순식',
#  '기자',
#  '헤럴드',
#  '뉴스',
#  '헤럴드',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '규모',
#  '생수',
#  '회사',
#  '자산',
#  '양수',
#  '방식',
#  '인수',
#  '추진',
#  '인수',
#  '완료',
#  '다음',
#  '글로벌',
#  '생수',
#  '시장',
#  '진출',
#  '영업',
#  '예정',
#  '인수',
#  '추진',
#  '회사',
#  '염분',
#  '제거',
#  '미네랄',
#  '선택',
#  '추출',
#  '원천',
#  '기술',
#  '보유',
#  '전문',
#  '기업',
#  '주요',
#  '제품',
#  '해양',
#  '심층수',
#  '화장품',
#  '처리',
#  '소금',
#  '자체',
#  '브랜드',
#  '생산',
#  '품질',
#  '입지',
#  '조건',
#  '장기',
#  '사업',
#  '운영',
#  '우위',
#  '핵심',
#  '기술',
#  '바탕',
#  '연구',
#  '개발',
#  '활동',
#  '다수',
#  '제품군',
#  '보유',
#  '글로벌',
#  '기존',
#  '영업',
#  '정비',
#  '하반기',
#  '생수',
#  '매출',
#  '이상',
#  '매출',
#  '증대',
#  '목표',
#  '공장',
#  '가동',
#  '증대',
#  '원가',
#  '절감',
#  '물량',
#  '증대',
#  '간수',
#  '화장수',
#  '고부',
#  '가치',
#  '상품',
#  '매출',
#  '증대',
#  '집중',
#  '계획',
#  '프리미엄',
#  '워터',
#  '출시',
#  '브랜드',
#  '이미지',
#  '제고',
#  '방침',
#  '글로벌',
#  '향후',
#  '관련',
#  '회사',
#  '시너지',
#  '영업',
#  '강화',
#  '대용량',
#  '생수',
#  '시장',
#  '진출',
#  '시설',
#  '투자',
#  '사업',
#  '제휴',
#  '기업',
#  '유통망',
#  '연계',
#  '프로덕트',
#  '공급',
#  '증대',
#  '추진',
#  '목표',
#  '일본',
#  '계열사',
#  '일본',
#  '시장',
#  '수출',
#  '기대',
#  '글로벌',
#  '계열',
#  '메이드',
#  '음료',
#  '사업',
#  '전개',
#  '지속',
#  '성장',
#  '계획',
#  '성공',
#  '투자',
#  '지름길',
#  '오늘',
#  '추천',
#  '오늘',
#  '증권',
#  '정보',
#  '재야',
#  '고수',
#  '종목',
#  '테마주',
#  '성공',
#  '투자',
#  '프로페셔널',
#  '포트폴리오',
#  '김경원',
#  '기자',
#  '저작',
#  '리얼타임',
#  '뉴스',
#  '머니',
#  '투데이',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '인터넷',
#  '커뮤니티',
#  '네비',
#  '스탁',
#  '소액',
#  '주주',
#  '결권',
#  '결과',
#  '글로벌',
#  '지분',
#  '보유',
#  '공시',
#  '성공',
#  '투자',
#  '지름길',
#  '오늘',
#  '추천',
#  '오늘',
#  '증권',
#  '정보',
#  '상승',
#  '포착',
#  '특징',
#  '휴대폰',
#  '특별',
#  '투자',
#  '코치',
#  '모바일',
#  '익스프레스',
#  '박성희',
#  '기자',
#  '저작',
#  '리얼타임',
#  '뉴스',
#  '머니',
#  '투데이',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '운영',
#  '자금',
#  '조달',
#  '특수',
#  '관계',
#  '메이드',
#  '밤비',
#  '대상',
#  '제자',
#  '배정',
#  '유상',
#  '증자',
#  '발행',
#  '결정',
#  '공시',
#  '신주',
#  '규모',
#  '만주',
#  '액면',
#  '가액',
#  '납입',
#  '이날',
#  '신주',
#  '교부',
#  '예정일',
#  '글로벌',
#  '납입',
#  '규모',
#  '메이드',
#  '남방',
#  '대상',
#  '배정',
#  '유상',
#  '증자',
#  '신주',
#  '배정자',
#  '청약',
#  '주금',
#  '미납',
#  '불발',
#  '공시',
#  '한경',
#  '닷컴',
#  '정인지',
#  '기자',
#  '오늘',
#  '추천',
#  '종목',
#  '최고',
#  '승부',
#  '나만',
#  '투자',
#  '정보',
#  '메신저',
#  '주일',
#  '무료',
#  '체험',
#  '성공',
#  '습관',
#  '한경',
#  '닷컴',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '한국',
#  '온라인',
#  '신문',
#  '협회',
#  '디지털',
#  '뉴스',
#  '이용',
#  '규칙',
#  '저작',
#  '행사',
#  '글로벌',
#  '유상',
#  '증자',
#  '대금',
#  '납입',
#  '글로벌',
#  '오후',
#  '유상',
#  '증자',
#  '결정',
#  '정정',
#  '공시',
#  '유상',
#  '증자',
#  '대금',
#  '납입',
#  '기일',
#  '기존',
#  '주일',
#  '변경',
#  '공시',
#  '증자',
#  '대금',
#  '납입',
#  '변경',
#  '이번',
#  '글로벌',
#  '지난달',
#  '운영',
#  '자금',
#  '마련',
#  '박지우',
#  '대표',
#  '대주주',
#  '메이드',
#  '대표',
#  '부인',
#  '비씨',
#  '대상',
#  '규모',
#  '제자',
#  '배정',
#  '유상',
#  '증자',
#  '결정',
#  '공시',
#  '공시',
#  '당시',
#  '글로벌',
#  '증자',
#  '대금',
#  '납입',
#  '발표',
#  '지난달',
#  '정정',
#  '공시',
#  '납입',
#  '변경',
#  '연기',
#  '지난달',
#  '회사',
#  '증자',
#  '대금',
#  '납입',
#  '월일',
#  '변경',
#  '납입',
#  '변경',
#  '증자',
#  '대금',
#  '마련',
#  '신호',
#  '대목',
#  '투자자',
#  '불안감',
#  '실제',
#  '현재',
#  '글로벌',
#  '거래일',
#  '하락',
#  '지난달',
#  '이후',
#  '글로벌',
#  '주가',
#  '거래일',
#  '하락',
#  '기록',
#  '액면가',
#  '양상',
#  '정순식',
#  '기자',
#  '헤럴드',
#  '뉴스',
#  '헤럴드',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '운영',
#  '자금',
#  '마련',
#  '보통주',
#  '메이드',
#  '밤비',
#  '대상',
#  '제자',
#  '배정',
#  '방식',
#  '유상',
#  '증자',
#  '공시',
#  '회사',
#  '관계자',
#  '유상',
#  '증자',
#  '납입',
#  '이후',
#  '배정',
#  '대상자',
#  '메이드',
#  '본사',
#  '최대',
#  '주주',
#  '채주',
#  '연기자',
#  '휴대폰',
#  '주가',
#  '조회',
#  '숫자',
#  '관심',
#  '종목',
#  '조회',
#  '주식',
#  '매매',
#  '서비스',
#  '글로벌',
#  '운영',
#  '자금',
#  '마련',
#  '메이드',
#  '밤비',
#  '대상',
#  '규모',
#  '제자',
#  '배정',
#  '유상',
#  '증자',
#  '결정',
#  '공시',
#  '성공',
#  '투자',
#  '지름길',
#  '오늘',
#  '추천',
#  '증권',
#  '정보',
#  '재야',
#  '고수',
#  '박성희',
#  '기자',
#  '저작',
#  '리얼타임',
#  '뉴스',
#  '머니',
#  '투데이',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '일본',
#  '조명',
#  '업체',
#  '어스',
#  '시스템',
#  '지분',
#  '투자',
#  '관련',
#  '양해',
#  '각서',
#  '체결',
#  '글로벌',
#  '토대',
#  '회계',
#  '가치',
#  '평가',
#  '지분',
#  '취득',
#  '계약',
#  '체결',
#  '어스',
#  '시스템',
#  '글로벌',
#  '일본',
#  '계열사',
#  '편입',
#  '계획',
#  '검토',
#  '어스',
#  '시스템',
#  '일본',
#  '조명',
#  '시장',
#  '올해',
#  '매출',
#  '기대',
#  '업체',
#  '파워',
#  '카메라',
#  '모듈',
#  '조명',
#  '모듈',
#  '전광',
#  '표시판',
#  '형광등',
#  '특허',
#  '보유',
#  '일본',
#  '최대',
#  '유통',
#  '사인',
#  '납품',
#  '계약',
#  '추진',
#  '기린',
#  '맥주',
#  '개발',
#  '의뢰',
#  '상태',
#  '기린',
#  '맥주',
#  '거래',
#  '거대',
#  '프랜차이즈',
#  '업체',
#  '다이',
#  '카우',
#  '기린',
#  '맥주',
#  '납품',
#  '규모',
#  '기대',
#  '어스',
#  '시스템',
#  '후지',
#  '전기',
#  '납품',
#  '계약',
#  '체결',
#  '이오니아',
#  '계열사',
#  '링크',
#  '비전',
#  '판매',
#  '대리점',
#  '활용',
#  '일본',
#  '시장',
#  '정부',
#  '시책',
#  '시바',
#  '백열전구',
#  '생산',
#  '중단',
#  '발표',
#  '가운데',
#  '미쓰',
#  '미시',
#  '전기',
#  '오스람',
#  '등도',
#  '생산',
#  '판매',
#  '중단',
#  '야노',
#  '경제',
#  '연구소',
#  '초대',
#  '디스플레이',
#  '표시기',
#  '세계',
#  '시장',
#  '예상',
#  '글로벌',
#  '관계자',
#  '최근',
#  '일본',
#  '조명',
#  '시장',
#  '기업',
#  '대중',
#  '시장',
#  '한국',
#  '기업',
#  '진출',
#  '환경',
#  '관계자',
#  '환경',
#  '관심',
#  '친환경',
#  '조명기',
#  '구로',
#  '주목',
#  '국내',
#  '해외',
#  '시장',
#  '전망',
#  '종료',
#  '공시',
#  '코스닥',
#  '종료',
#  '공시',
#  '코스닥',
#  '마이크',
#  '박지우',
#  '대표',
#  '이사',
#  '신규',
#  '선임',
#  '타마이',
#  '크로',
#  '글로벌',
#  '사명',
#  '변경',
#  '콘텐츠',
#  '제작사',
#  '음원',
#  '전쟁',
#  '수혜',
#  '부각',
#  '아시아',
#  '경제',
#  '증권',
#  '방송',
#  '선착순',
#  '경품',
#  '제공',
#  '벤트',
#  '박형수',
#  '기자',
#  '세계',
#  '경제',
#  '아시아',
#  '경제',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '지난해',
#  '매출액',
#  '영업',
#  '손실',
#  '기록',
#  '전년',
#  '감소',
#  '공시',
#  '양재혁',
#  '기자',
#  '저작',
#  '파이낸셜',
#  '뉴스',
#  '무단',
#  '전재',
#  '배포',
#  '금지',
#  '글로벌',
#  '지난해',
#  '영업',
#  '손실',
#  '억만',
#  '기록',
#  '전년',
#  '대비',
#  '자폭',
#  '확대',
#  '공시',
#  '매출액',
#  '감소',
#  '억만',
#  '기록',
#  '당기',
#  '순손실',
#  '억만',
#  '적자',
#  '지속',
#  '성공',
#  '투자',
#  '지름길',
#  '오늘',
#  '추천',
#  '증권',
#  '정보',
#  '재야',
#  '고수',
#  '정영일',
#  '기자',
#  ...]

# %%
c = Counter(list_text_1) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함
print(c)
# Out:
# Counter({'공시': 3136, '경제': 2510, '기업': 2458, '상장': 2452, '종목': 2268, '금지': 2240, '배포': 2176, '뉴스': 2137, '무단': 2070, '전재': 2063, '규모': 2059, '투자': 1937, '시장': 1929, '결정': 1868, '사업': 1730, '한국': 1692, '기자': 1681, '정보': 1673, '회사': 1624, '코스닥': 1584, '대표': 1576, '증자': 1537, '주식': 1500, '억만': 1497, '주가': 1496, '데일리': 1433, '영업': 1414, '자금': 1328, '폐지': 1309, '유상': 1259, '기록': 1227, '계약': 1218, '지난해': 1209, '증권': 1195, '거래': 1144, '주주': 1144, '관리': 1102, '업체': 1073, '에스': 1066, '저작': 1050, '발행': 1035, '금융': 1020, '관련': 1015, '상승': 944, '대비': 930, '매매': 867, '지분': 867, '지정': 857, '최근': 855, '자본': 838, '개발': 832, '감사': 813, '최대': 809, '거래소': 808, '관계자': 777, '손실': 763, '하락': 755, '법인': 752, '투자자': 746, '이사': 744, '수익': 740, '경우': 736, '이익': 736, '전자': 731, '세계': 723, '신청': 713, '매출': 710, '실적': 707, '변경': 697, '이상': 693, '머니': 692, '투데이': 689, '매출액': 682, '분기': 677, '테크': 670, '가능': 664, '공급': 664, '성공': 661, '아시아': 661, '매수': 660, '국내': 658, '모바일': 646, '올해': 645, '진행': 643, '오늘': 642, '때문': 635, '바이오': 631, '의견': 621, '기간': 606, '발생': 600, '경영': 599, '종합': 598, '전년': 591, '추천': 584, '인수': 583, '증가': 579, '미디어': 578, '글로벌': 575, '지수': 571, '전환': 568, '체결': 564, '적자': 562, '이후': 555, '급등': 541, '예정': 540, '리얼타임': 538, '아이': 535, '서울': 535, '개선': 534, '조회': 534, '중국': 533, '제출': 532, '행사': 529, '이번': 527, '보유': 523, '서비스': 521, '시스템': 519, '대상': 515, '생산': 511, '이날': 501, '보고서': 501, '설명': 499, '기관': 496, '해외': 495, '공모': 492, '사유': 489, '만주': 489, '기술': 488, '운영': 487, '조달': 483, '기준': 476, '방송': 474, '실시간': 471, '쌍용건설': 471, '계획': 470, '매각': 461, '취득': 457, '홀딩스': 457, '은행': 456, '신주': 453, '정지': 448, '배정': 438, '절차': 438, '월일': 435, '횡령': 434, '심사': 429, '신문': 428, '가격': 428, '산업': 424, '마감': 423, '공개': 422, '추가': 421, '잠식': 419, '건설': 416, '요구': 413, '헤럴드': 411, '상황': 407, '이용': 406, '연속': 404, '에너지': 403, '여부': 398, '일반': 395, '씨모': 394, '당기': 390, '개인': 387, '신주인수권': 387, '회생': 385, '감소': 381, '코리아': 381, '감자': 379, '추진': 376, '해당': 375, '거절': 372, '회계': 372, '제품': 366, '상태': 363, '이유': 362, '증시': 361, '전망': 360, '전기': 360, '상한가': 360, '구조': 358, '지원': 356, '처분': 349, '외국인': 346, '회장': 344, '기사': 339, '공사': 337, '업계': 335, '금액': 335, '소식': 334, '자기': 333, '위기': 332, '신규': 330, '매도': 327, '삼성': 324, '무료': 322, '통신': 322, '보통주': 321, '법원': 321, '결과': 320, '확보': 315, '방식': 314, '재무': 312, '합병': 312, '일본': 310, '업종': 310, '우리': 309, '판매': 308, '현대': 308, '실질': 307, '성장': 306, '자산': 304, '기존': 303, '마련': 303, '법정': 303, '확인': 302, '급락': 301, '대출': 301, '채권': 300, '전문가': 299, '지난달': 294, '개월': 292, '닷컴': 289, '예상': 289, '검토': 288, '전문': 287, '디지털': 285, '반도체': 283, '참여': 282, '조선': 281, '현재': 280, '흑자': 280, '제공': 279, '순손실': 279, '반기': 277, '기대': 277, '개사': 277, '스마트': 275, '장사': 274, '순이익': 271, '청약': 270, '분석': 270, '동양': 270, '배임': 268, '포착': 264, '확대': 264, '웍스': 264, '협력': 264, '온라인': 263, '지속': 263, '코스피': 263, '필요': 263, '평가': 262, '하루': 261, '부사': 260, '가운데': 259, '성실': 259, '우려': 259, '거래일': 258, '결국': 258, '시작': 256, '가액': 255, '미국': 254, '한경': 253, '특징': 253, '퇴출': 253, '전날': 251, '상환': 251, '충격': 251, '하한가': 249, '소액': 249, '발표': 248, '전일': 248, '제한': 246, '제조': 246, '사실': 246, '동안': 245, '제자': 244, '실시': 242, '솔루션': 242, '다음': 241, '대금': 240, '사용': 240, '보증': 239, '유니': 238, '재테크': 237, '거래량': 237, '수준': 237, '문제': 237, '파이낸셜': 235, '에프': 235, '혐의': 234, '어디': 233, '반면': 231, '조정': 229, '지앤': 227, '자동차': 225, '상담': 223, '진출': 222, '주요': 221, '삼성전자': 221, '사항': 221, '일부': 221, '휴대폰': 220, '제약': 216, '주당': 216, '자회사': 216, '포함': 216, '정도': 215, '정상': 214, '선임': 213, '확정': 213, '답변': 213, '협회': 212, '내년': 212, '부품': 211, '네오': 210, '연도': 208, '신용': 207, '지방': 207, '뉴시스': 207, '본부': 206, '포인트': 205, '케이': 205, '내용': 205, '관심': 204, '습관': 203, '특허': 203, '종료': 203, '유지': 203, '동기': 202, '제기': 201, '강세': 201, '중앙': 201, '상반기': 201, '휴먼': 200, '터미널': 199, '출시': 199, '지름길': 199, '목적': 198, '물량': 195, '하나': 195, '단기': 194, '시가총액': 194, '플러스': 194, '권단': 194, '아이디': 193, '최고': 192, '증권사': 192, '제시': 191, '고수': 188, '안방': 187, '그 ...

# %%
c
# Out:
# Counter({'글로벌': 575,
#          '반기': 277,
#          '검토': 288,
#          '의견': 621,
#          '거절': 372,
#          '관리': 1102,
#          '종목': 2268,
#          '지정': 857,
#          '사유': 489,
#          '발생': 600,
#          '공시': 3136,
#          '한국': 1692,
#          '거래소': 808,
#          '주권': 160,
#          '매매': 867,
#          '거래': 1144,
#          '정지': 448,
#          '한경': 253,
#          '닷컴': 289,
#          '최성남': 10,
#          '기자': 1681,
#          '오늘': 642,
#          '추천': 584,
#          '기습': 13,
#          '극비': 17,
#          '세력': 30,
#          '밸류': 28,
#          '무료': 322,
#          '체험': 22,
#          '당첨': 18,
#          '이벤트': 131,
#          '성공': 661,
#          '습관': 203,
#          '무단': 2070,
#          '전재': 2063,
#          '배포': 2176,
#          '금지': 2240,
#          '온라인': 263,
#          '신문': 428,
#          '협회': 212,
#          '디지털': 285,
#          '뉴스': 2137,
#          '이용': 406,
#          '규칙': 166,
#          '저작': 1050,
#          '행사': 529,
#          '신용': 207,
#          '등급': 113,
#          '기존': 303,
#          '하향': 37,
#          '조정': 229,
#          '신정': 2,
#          '평가': 262,
#          '정평': 5,
#          '금융': 1020,
#          '기관': 496,
#          '신인': 5,
#          '저하': 5,
#          '주력': 90,
#          '사업': 1730,
#          '약화': 8,
#          '수익': 740,
#          '기반': 95,
#          '대폭': 10,
#          '축소': 80,
#          '신규': 330,
#          '소송': 172,
#          '관련': 1015,
#          '우발': 5,
#          '채무': 133,
#          '현실': 47,
#          '가능': 664,
#          '고려': 133,
#          '이번': 527,
#          '배경': 31,
#          '설명': 499,
#          '향후': 186,
#          '의미': 69,
#          '전망': 360,
#          '부정': 32,
#          '저조': 20,
#          '현금': 148,
#          '흐름': 134,
#          '지속': 263,
#          '예상': 289,
#          '가운데': 259,
#          '전개': 19,
#          '투자': 1937,
#          '부담': 123,
#          '데일리': 1433,
#          '문자': 147,
#          '시세': 166,
#          '진단': 172,
#          '상담': 223,
#          '정보': 1673,
#          '모바일': 646,
#          '실시간': 471,
#          '해외': 495,
#          '지수': 571,
#          '경제': 2510,
#          '터미널': 199,
#          '종합': 598,
#          '미디어': 578,
#          '안방': 187,
#          '재테크': 237,
#          '이태호': 1,
#          '감자': 379,
#          '결의': 122,
#          '주주': 1144,
#          '총회': 157,
#          '다음': 241,
#          '기준일': 29,
#          '월일': 435,
#          '재무': 312,
#          '구조': 358,
#          '개선': 534,
#          '최대': 809,
#          '메이드': 17,
#          '밤비': 4,
#          '대상': 515,
#          '규모': 2059,
#          '유상': 1259,
#          '증자': 1537,
#          '실시': 242,
#          '참여': 282,
#          '만주': 489,
#          '보유': 523,
#          '안재만': 34,
#          '거래일': 258,
#          '연속': 404,
#          '하한가': 249,
#          '기록': 1227,
#          '주가': 1496,
#          '위협': 17,
#          '오전': 178,
#          '시작': 256,
#          '가격': 428,
#          '제한': 246,
#          '시분': 95,
#          '거래량': 237,
#          '잔량': 12,
#          '현재': 280,
#          '여주': 39,
#          '개인': 387,
#          '계좌': 143,
#          '투자주': 82,
#          '전체': 129,
#          '주식': 1500,
#          '수의': 6,
#          '해당': 375,
#          '매도': 327,
#          '물량': 195,
#          '결과': 320,
#          '현상': 44,
#          '이날': 501,
#          '증권': 1195,
#          '창구': 27,
#          '규정': 88,
#          '당일': 58,
#          '정규': 8,
#          '시장': 1929,
#          '특정': 28,
#          '매수': 660,
#          '수량': 13,
#          '상장주': 22,
#          '식수': 52,
#          '대비': 930,
#          '이상': 693,
#          '종가': 77,
#          '전날': 251,
#          '상승': 944,
#          '생수': 9,
#          '회사': 1624,
#          '자산': 304,
#          '양수': 112,
#          '방식': 314,
#          '인수': 583,
#          '추진': 376,
#          '언론': 84,
#          '대표': 1576,
#          '이사': 744,
#          '상대': 94,
#          '신주': 453,
#          '발행': 1035,
#          '무효': 21,
#          '제기': 201,
#          '취하': 47,
#          '보도': 109,
#          '역행': 1,
#          '모습': 137,
#          '입장': 133,
#          '정순식': 2,
#          '헤럴드': 411,
#          '완료': 153,
#          '진출': 222,
#          '영업': 1414,
#          '예정': 540,
#          '염분': 1,
#          '제거': 17,
#          '미네랄': 2,
#          '선택': 106,
#          '추출': 4,
#          '원천': 15,
#          '기술': 488,
#          '전문': 287,
#          '기업': 2458,
#          '주요': 221,
#          '제품': 366,
#          '해양': 56,
#          '심층수': 1,
#          '화장품': 96,
#          '처리': 120,
#          '소금': 2,
#          '자체': 101,
#          '브랜드': 65,
#          '생산': 511,
#          '품질': 46,
#          '입지': 19,
#          '조건': 85,
#          '장기': 67,
#          '운영': 487,
#          '우위': 120,
#          '핵심': 89,
#          '바탕': 45,
#          '연구': 143,
#          '개발': 832,
#          '활동': 77,
#          '다수': 37,
#          '제품군': 11,
#          '정비': 12,
#          '하반기': 99,
#          '매출': 710,
#          '증대': 44,
#          '목표': 132,
#          '공장': 183,
#          '가동': 32,
#          '원가': 68,
#          '절감': 70,
#          '간수': 1,
#          '화장수': 1,
#          '고부': 12,
#          '가치': 154,
#          '상품': 170,
#          '집중': 133,
#          '계획': 470,
#          '프리미엄': 58,
#          '워터': 6,
#          '출시': 199,
#          '이미지': 72,
#          '제고': 38,
#          '방침': 78,
#          '시너지': 59,
#          '강화': 150,
#          '대용량': 14,
#          '시설': 137,
#          '제휴': 90,
#          '유통망': 1,
#          '연계': 57,
#          '프로덕트': 2,
#          '공급': 664,
#          '일본': 310,
#          '계열사': 152,
#          '수출': 161,
#          '기대': 277,
#          '계열': 54,
#          '음료': 3,
#          '성장': 306,
#          '지름길': 199,
#          '재야': 43,
#          '고수': 188,
#          '테마주': 107,
#          '프로페셔널': 8,
#          '포트폴리오': 37,
#          '김경원': 3,
#          '리얼타임': 538,
#          '머니': 692,
#          '투데이': 689,
#          '인터넷': 183,
#          '커뮤니티': 10,
#          '네비': 16,
#          '스탁': 82,
#          '소액': 249,
#          '결권': 10,
#          '지분': 867,
#          '포착': 264,
#          '특징': 253,
#          '휴대폰': 220,
#          '특별': 152,
#          '코치': 87,
#          '익스프레스': 92,
#          '박성희': 6,
#          '자금': 1328,
#          '조달': 483,
#          '특수': 108,
#          '관계': 150,
#          '제자': 244,
#          '배정': 438,
#          '결정': 1868,
#          '액면': 28,
#          '가액': 255,
#          '납입': 170,
#          '교부': 17,
#          '예정일': 151,
#          '남방': 6,
#          '배정자': 4,
#          '청약': 270,
#          '주금': 6,
#          '미납': 12,
#          '불발': 22,
#          '정인지': 15,
#          '최고': 192,
#          '승부': 27,
#          '나만': 3,
#          '메신저': 6,
#          '주일': 30,
#          '대금': 240,
#          '오후': 176,
#          '정정': 155,
#          '기일': 22,
#          '변경': 697,
#          '지난달': 294,
#          '마련': 303,
#          '박지우': 7,
#          '대주주': 135,
#          '부인': 29,
#          '비씨': 13,
#          '당시': 125,
#          '발표': 248,
#          '연기': 102,
#          '신호': 18,
#          '대목': 8,
#          '투자자': 746,
#          '불안감': 18,
#          '실제': 85,
#          '하락': 755,
#          '이후': 555,
#          '액면가': 45,
#          '양상': 17,
#          '보통주': 321,
#          '관계자': 777,
#          '대상자': 73,
#          '본사': 66,
#          '채주': 3,
#          '연기자': 25,
#          '조회': 534,
#          '숫자': 56,
#          '관심': 204,
#          '서비스': 521,
#          '조명': 173,
#          '업체': 1073,
#          '어스': 6,
#          '시스템': 519,
#          '양해': 28,
#          '각서': 28,
#          '체결': 564,
#          '토대': 13,
#          '회계': 372,
#          '취득': 457,
#          '계약': 1218,
#          '편입': 88,
#          '올해': 645,
#          '파워': 148,
#          '카메라': 37,
#          '모듈': 124,
#          '전광': 1,
#          '표시판': 1,
#          '형광등': 1,
#          '특허': 203,
#          '유통': 150,
#          '사인': 14,
#          '납품': 90,
#          '기린': 4,
#          '맥주': 24,
#          '의뢰': 14,
#          '상태': 363,
#          '거대': 9,
#          '프랜차이즈': 15,
#          '다이': 1,
#          '카우': 4,
#          '후지': 3,
#          '전기': 360,
#          '이오니아': 1,
#          '링크': 12,
#          '비전': 23,
#          '판매': 308,
#          '대리점': 11,
#          '활용': 117,
#          '정부': 158,
#          '시책': 1,
#          '시바': 1,
#          '백열전구': 3,
#          '중단': 113,
#          '미쓰': 3,
#          '미시': 1,
#          '오스람': 9,
#          '등도': 2,
#          '야노': 1,
#          '연구소': 54,
#          '초대': 20,
#          '디스플레이': 121,
#          '표시기': 2,
#          '세계': 723,
#          '최근': 855,
#          '대중': 14,
#          '환경': 88,
#          '친환경': 47,
#          '조명기': 1,
#          '구로': 1,
#          '주목': 119,
#          '국내': 658,
#          '종료': 203,
#          '코스닥': 1584,
#          '마이크': 91,
#          '선임': 213,
#          '타마이': 2,
#          '크로': 6,
#          '사명': 60,
#          '콘텐츠': 74,
#          '제작사': 9,
#          '음원': 13,
#          '전쟁': 34,
#          '수혜': 72,
#          '부각': 36,
#          '아시아': 661,
#          '방송': 474,
#          '선착순': 7,
#          '경품': 8,
#          '제공': 279,
#          '벤트': 1,
#          '박형수': 23,
#          '지난해': 1209,
#          '매출액': 682,
#          '손실': 763,
#          '전년': 591,
#          '감소': 381,
#          '양재혁': 3,
#          '파이낸셜': 235,
#          '억만': 1497,
#          '자폭': 31,
#          '확대': 264,
#          '당기': 390,
#          '순손실': 279,
#          '적자': 562,
#          '정영일': 20,
#          '단기': 194,
#          '급등': 541,
#          '장중': 111,
#          '심리': 60,
#          '낙폭': 55,
#          '무색': 2,
#          '정도': 215,
#          '미국': 254,
#          '증시': 361,
#          '소폭': 66,
#          '단기간': 21,
#          '요인': 48,
#          '작용': 88,
#          '유동': 170,
#          '외국인': 346,
#          '사자': 19,
#          '행진': 54,
#          '계속': 78,
#          '코스피': 263,
#          '포인트': 205,
#          '어치': 60,
#          '분위기': 48,
#          '희석': 12,
#          '조억': 108,
#          '운송': 57,
#          '장비': 183,
#          '가스': 80,
#          '순매도': 180,
#          '수급': 61,
#          '영향': 146,
#          '배당': 96,
#          '매력': 29,
#          '내수': 22,
#          '방어주': 3,
#          '선방': 7,
#          '의료': 70,
#          '정밀': 62,
#          '건설': 416,
#          '운수': 14,
#          '창고': 12,
#          '비금속': 25,
#          '광물': 15,
#          '내외': 15,
#          '반면': 231,
#          '그간': 30,
#          '화학': 181,
#          '기계': 89,
#          '전자': 731,
#          '미만': 94,
#          '시가총액': 194,
#          '상위': 168,
#          '한국전력': 26,
#          '포스코': 101,
#          '신한': 54,
#          '지주': 81,
#          '오름폭': 2,
#          '기아차': 76,
#          '삼성전자': 221,
#          '약세': 140,
#          '삼성': 324,
#          '생명': 99,
#          '현대': 308,
#          '중공업': 91,
#          '선물': 97,
#          '보합': 47,
#          '마감': 423,
#          '간밤': 2,
#          '뉴욕': 35,
#          '시즌': 39,
#          '경계': 18,
#          '확산': 50,
#          '초반': 45,
#          '주문': 29,
#          '오류': 8,
#          '호재': 52,
#          '방향': 48,
#          '실패': 101,
#          '출발': 66,
#          '호가': 18,
#          '잘못': 8,
#          '반전': 68,
#          '현물': 7,
#          '하락세': 76,
#          '베이시스': 7,
#          '후반': 23,
#          '상승세': 121,
#          '탱고': 4,
#          '프로그램': 102,
#          '유지': 203,
#          '포지션': 2,
#          '청산': 30,
#          '미결제': 8,
#          '약정': 18,
#          '호조': 20,
#          '이틀': 141,
#          '매수세': 56,
#          '전일': 248,
#          '업종': 310,
#          '섬유': 52,
#          '의류': 37,
#          '반도체': 283,
#          '하드웨어': 20,
#          '부품': 211,
#          '약보합': 21,
#          '오락': 29,
#          '컴퓨터': 90,
#          '제약': 216,
#          '기기': 102,
#          '강세': 201,
#          '투미': 6,
#          '비티': 23,
#          '웰메이드': 24,
#          '패스': 57,
#          '하이쎌': 20,
#          '유성': 27,
#          '티엔': 15,
#          '에스': 1066,
#          '폴리비전': 21,
#          '디브이': 60,
#          '급락': 301,
#          '봉신': 10,
#          '동원금속': 7,
#          '롯데': 76,
#          '관광': 29,
#          '상한가': 360,
#          '우리': 309,
#          '디스': 22,
#          '아티스': 13,
#          '샤넬': 8,
#          '에르메스': 5,
#          '개념': 26,
#          '명품': 76,
#          '시대': 101,
#          '유튜브': 12,
#          '지하철': 39,
#          '난투극': 5,
#          '여학생': 5,
#          '피해자': 21,
#          '청년': 22,
#          '창업': 129,
#          '소셜': 13,
#          '커머스': 19,
#          '벤츠': 40,
#          '페라리': 18,
#          '포르쉐': 10,
#          '디자인': 100,
#          '쏘나타': 29,
#          '직접': 20,
#          '정영화': 3,
#          '동화': 32,
#          '홀딩스': 457,
#          '외환은행': 27,
#          '자사': 56,
#          '신탁': 35,
#          '기간': 606,
#          '연장': 82,
#          '유티': 2,
#          '엑스': 20,
#          '정수': 1,
#          '이성암': 1,
#          '멕스': 24,
#          '퍼스트': 7,
#          '에이스': 119,
#          '홍석윤': 1,
#          '신세계': 19,
#          '푸드': 35,
#          '주당': 216,
#          '신한은행': 23,
#          '이화공영': 12,
#          '인천': 51,
#          '지방': 207,
#          '조달청': 13,
#          '발주': 80,
#          '경기도': 36,
#          '화성': 34,
#          '국제': 109,
#          '신축': 23,
#          '공사': 337,
#          '수주': 172,
#          '유업': 10,
#          '상하': 14,
#          '흡수': 73,
#          '합병': 312,
#          '배우': 42,
#          '김세준': 1,
#          '사기': 19,
#          '벌금': 12,
#          '천만': 97,
#          '드라마': 25,
#          '동시': 85,
#          '출연': 28,
#          '신예': 2,
#          '정이연': 1,
#          '공유': 61,
#          '이민정': 5,
#          '커플': 8,
#          '화보': 66,
#          '공개': 422,
#          '생각': 73,
#          '박현빈': 1,
#          '월드컵': 5,
#          '응원': 7,
#          '김은별': 6,
#          '상호': 80,
#          '상장': 2452,
#          '강두순': 1,
#          '등락': 68,
#          '출회': 8,
#          '결국': 258,
#          '김성호': 20,
#          '장사': 274,
#          '마이크로': 23,
#          '멕시코': 12,
#          '선인장': 2,
#          '열매': 2,
#          '농축': 10,
#          '원액': 4,
#          '음식료': 29,
#          '풀무원': 12,
#          '남승우': 1,
#          '이달초': 2,
#          '경영': 599,
#          '임시': 107,
#          '사진': 111,
#          '박완수': 1,
#          '부사장': 34,
#          '김용인': 1,
#          '사내': 47,
#          '박철순': 1,
#          '교수': 63,
#          '최정욱': 1,
#          '이경묵': 1,
#          '사외': 43,
#          '하얏트': 4,
#          '호텔': 41,
#          '명회': 39,
#          '준비': 81,
#          '골프장': 20,
#          '리조트': 9,
#          '점막': 2,
#          '보호': 126,
#          '효과': 168,
#          '항산': 1,
#          '실험': 16,
#          '입증': 32,
#          '건강': 38,
#          '식품': 65,
#          '분야': 131,
#          '원료': 21,
#          '그것': 14,
#          '포부': 11,
#          '현지': 72,
#          '설립': 122,
#          '동의': 18,
#          '미겔': 1,
#          '비야르': 1,
#          '주한': 6,
#          '상무관': 1,
#          '약속': 27,
#          '적극': 130,
#          '연평균': 5,
#          '샘물': 4,
#          '때문': 635,
#          '엔키': 1,
#          '장악': 13,
#          '경쟁력': 93,
#          '실적': 707,
#          '자신감': 19,
#          '기사': 339,
#          '개최': 109,
#          '유료': 16,
#          '전화': 99,
#          '네이처': 9,
#          '병합': 72,
#          '자본': 838,
#          '자본금': 111,
#          '안현덕': 19,
#          '식양': 2,
#          '수도': 19,
#          '작년': 133,
#          '달성': 114,
#          '스카이': 33,
#          '테크': 670,
#          '공동': 157,
#          '자동판매기': 2,
#          '전역': 8,
#          '주유소': 7,
#          '가량': 136,
#          '주서': 1,
#          '온실가스': 11,
#          '삭감': 5,
#          '공략': 46,
#          '과제': 19,
#          '정책': 65,
#          '추후': 38,
#          '냉동': 6,
#          '패스트푸드': 1,
#          '약국': 2,
#          '가라오케': 1,
#          '간판': 11,
#          '자회사': 216,
#          '실질': 307,
#          '성과': 83,
#          '추가': 421,
#          '동서': 34,
#          '결산': 172,
#          '기준': 476,
#          '실리콘': 35,
#          '전등갓': 2,
#          '제조': 246,
#          '방법': 183,
#          '주지훈': 1,
#          '훈련소': 1,
#          '입소': 2,
#          '동방신기': 3,
#          '싱글': 2,
#          '가수': 42,
#          '최다': 8,
#          '남상미': 1,
#          '인생': 23,
#          '확정': 213,
#          '정가은': 1,
#          '예능': 2,
#          '스타일': 10,
#          '신은경': 3,
#          '지명': 5,
#          '수배': 4,
#          '까닭': 11,
#          '법인': 752,
#          '성실': 259,
#          '유가증권': 115,
#          '코스모': 8,
#          '은박지': 4,
#          '와이어리스': 113,
#          '아이디': 193,
#          '히스': 112,
#          '토스': 119,
#          '유비': 113,
#          '트론': 36,
#          '하이텍': 112,
#          '올리브나인': 8,
#          '중지': 15,
#          '제외': 111,
#          '개사': 277,
#          '하루': 261,
#          '한편': 164,
#          '폐지': 1309,
#          '오세미': 25,
#          '지연': 143,
#          '의혹': 67,
#          '업계': 335,
#          '세상': 117,
#          '미스코리아': 7,
#          '수상자': 44,
#          '모임': 10,
#          '원회': 1,
#          '하이브리드': 16,
#          '차량': 107,
#          '사이트': 36,
#          '내달': 60,
#          '상륙': 14,
#          '시노': 77,
#          '트러스트': 1,
#          '레이': 17,
#          '사장': 139,
#          '가을': 7,
#          '로또': 17,
#          '단골': 3,
#          '번호': 16,
#          '공부': 86,
#          '주제': 37,
#          '강주': 2,
#          '요구': 413,
#          '부동산': 83,
#          '매각': 461,
#          '진행': 643,
#          '답변': 213,
#          '파스': 47,
#          '무상': 73,
#          '권리락': 27,
#          '울트라건설': 104,
#          '단일': 38,
#          '바이오': 631,
#          '가급': 1,
#          '변지': 1,
#          '오멘': 1,
#          '토현': 1,
#          '횡령': 434,
#          '배임': 268,
#          '혐의': 234,
#          '소설': 10,
#          '검찰': 117,
#          '조사': 118,
#          '확인': 302,
#          '사항': 221,
#          '트리': 113,
#          '밀러': 10,
#          '임상': 58,
#          '시험': 48,
#          '승인': 70,
#          '큐릭스': 9,
#          '네트': 169,
#          '웍스': 264,
#          '서대문': 1,
#          '해산': 5,
#          '동일인': 1,
#          '출자': 105,
#          '케이': 205,
#          '씨씨': 2,
#          '용역': 27,
#          '바른손': 35,
#          '강원도': 4,
#          '평창군': 1,
#          '포레스트': 1,
#          '재평가': 20,
#          '증가': 579,
#          '단수': 1,
#          '실권주': 48,
#          '이남준': 1,
#          '발행가': 97,
#          '비츠': 22,
#          '시스': 179,
#          '권면': 32,
#          '총액': 99,
#          '신주인수권': 387,
#          '부사': 260,
#          '채권': 300,
#          '불성실': 55,
#          '동안': 245,
#          '지스': 16,
#          '판결': 63,
#          '미주': 55,
#          '제강': 97,
#          '추석': 33,
#          '극대': 48,
#          '비밀': 87,
#          '노트': 66,
#          '리치': 17,
#          '기법': 161,
#          '특급': 130,
#          '내역': 124,
#          '비법': 130,
#          '제시': 191,
#          '천우': 40,
#          '현직': 22,
#          '매임': 1,
#          '인네트': 6,
#          '부도': 48,
#          '여부': 398,
#          '구체': 118,
#          '내용': 205,
#          '번복': 57,
#          '예고': 128,
#          '범일': 1,
#          '인더스': 5,
#          '컬러': 8,
#          '화강석': 1,
#          '설과': 10,
#          '수사': 69,
#          '사실': 246,
#          '즉시': 15,
#          '영솔': 16,
#          '케이스': 17,
#          '조립': 11,
#          '전지': 83,
#          '음극': 1,
#          '이치': 107,
#          '서브': 6,
#          '구미': 2,
#          '자유투': 7,
#          '에프': 235,
#          '티엠': 3,
#          '성원': 99,
#          '파이프': 32,
#          '주채': 46,
#          '은행': 456,
#          '농협': 9,
#          '중앙': 201,
#          '대출': 301,
#          '전액': 98,
#          '상환': 251,
#          '전현': 8,
#          '감사': 813,
#          '임철': 10,
#          '네프': 181,
#          '아이': 535,
#          '환급': 14,
#          '조치': 110,
#          '다린': 20,
#          '웨스트': 34,
#          '협상': 78,
#          '대리인': 24,
#          '박태경': 19,
#          '일반': 395,
#          '공모': 492,
#          '증거금': 57,
#          '나머지': 52,
#          '출금': 6,
#          '회수': 99,
#          '영장': 13,
#          '발부': 7,
#          '추적': 25,
#          '인영': 1,
#          '송진우': 1,
#          '비등기': 1,
#          '김우용': 1,
#          '고소': 31,
#          '조선': 281,
#          '비즈': 110,
#          '연비': 22,
#          '불티': 3,
#          '추락': 85,
#          '화물기': 1,
#          '천억': 104,
#          '보상': 13,
#          '질주': 13,
#          '환율': 67,
#          '원도': 1,
#          '붕괴': 8,
#          '연말': 115,
#          '페루': 3,
#          '날개': 10,
#          '유치': 76,
#          '스톱': 9,
#          '위기': 332,
#          '우량': 42,
#          '유인': 1,
#          '필요': 263,
#          '소가': 1,
#          '작업': 88,
#          '곳곳': 7,
#          '암초': 2,
#          '사건': 101,
#          '중국': 533,
#          '코웰': 19,
#          '자진': 21,
#          '사모': 125,
#          '컴퍼니': 171,
#          '수준': 237,
#          '공개매수': 15,
#          '획득': 50,
#          '매입': 163,
#          '곽정환': 1,
#          '소유': 30,
#          '경우': 736,
#          '절차': 438,
#          '전환': 568,
#          '추구': 7,
#          '의사': 47,
#          '외국': 86,
#          '고섬': 26,
#          '잔액': 24,
#          '싱가포르': 25,
#          '사태': 71,
#          '상당': 74,
#          '어려움': 73,
#          ...})

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250,background_color='white')
gen = wc.generate_from_frequencies(c)
plt.figure(figsize=(6,8))

plt.imshow(gen)
wc.to_file('상폐_워드클라우드.png')
