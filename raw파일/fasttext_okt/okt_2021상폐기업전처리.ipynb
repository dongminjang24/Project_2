# %%
import pandas as pd
import numpy as np

# %%
df_2021=pd.read_csv('./data/2021기업_재무비율(2019).csv', encoding='cp949')
df_2021
# Out:
#              회사명   거래소코드     회계년도    자산(*)(연결)        자산(*)    영업이익(손실)  \
# 0       (주)CMG제약   58820  2019/12  192243166.0  192243166.0   2603774.0
# 1        (주)ES큐브   50120  2019/12  463958680.0  136065488.0    587700.0
# 2         (주)가비아   79940  2019/12  199916131.0   82964911.0   4889113.0
# 3     (주)강스템바이오텍  217730  2019/12  113643697.0   98625925.0 -19411148.0
# 4       (주)강원에너지  114190  2019/12   56602063.0   55106032.0 -17150531.0
# ...          ...     ...      ...          ...          ...         ...
# 1467    효성오앤비(주)   97870  2019/06   70203765.0   66580643.0   1331706.0
# 1468     휴림로봇(주)   90710  2019/12   42734247.0   41764854.0  -3879766.0
# 1469     휴마시스(주)  205470  2019/12          NaN   36487811.0   -875264.0
# 1470       휴젤(주)  145020  2019/12  894690014.0  848026074.0  41865498.0
# 1471     흥구석유(주)   24060  2019/12          NaN   83661499.0    500763.0
#
#       영업이익(손실)(연결)    부채(*)(연결)        부채(*)    자본(*)(연결)        자본(*)  \
# ...

# %%
상폐_df=pd.read_csv("./data/2021상폐기업_재무비율(2019).csv",encoding="cp949")

상폐_df
# Out:
#              회사명   거래소코드    회계년도    자산(*)(연결)        자산(*)    영업이익(손실)  \
# 0          (주)금빛   45890  Dec-19  102849215.0  101724359.0 -16662557.0
# 1        (주)맥스로텍  141070  Dec-19          NaN   75565720.0  -8517556.0
# 2       (주)미래SCI   28040  Dec-19   54405331.0   48377378.0  -5016986.0
# 3        (주)아이엠텍  226350  Dec-19   54274661.0   52827782.0  -2751188.0
# 4      (주)에스제이케이   80440  Dec-19   55342770.0   59723547.0  -4582413.0
# 5        (주)에이치디  102210  Dec-19  146820812.0  146820812.0  -2644956.0
# 6         (주)에이팸   73070  Dec-19  119641377.0  117564448.0  -5199063.0
# 7      (주)이매진아시아   36260  Dec-19   17924929.0   18295141.0  -3139370.0
# 8      (주)이엠네트웍스   87730  Dec-19   58841584.0   57032067.0  -4804316.0
# 9         (주)제낙스   65620  Dec-19   24780625.0   30175267.0  -6859726.0
# 10        (주)지유온  111820  Dec-19          NaN   25081604.0  -2286842.0
# 11   (주)코너스톤네트웍스   33110  Dec-19   79716591.0   64021459.0  -6822717.0
# ...

# %% [markdown]
# 상폐날짜랑 회사명외에 빼고 회사명 고쳐줌

# %%
상폐날짜유_df=pd.read_csv(r'C:\Users\jangd\OneDrive\사진\문서\GitHub\project2\상장폐지현황_21.csv',encoding='utf-8-sig')
상폐날짜유_df.drop(["폐지사유","비고","번호"],axis=1,inplace=True)
for i in range(20):
    상폐날짜유_df["회사명"][i]=상폐_df["회사명"][i]
상폐날짜유_df
# Out:
# C:\Users\jangd\AppData\Local\Temp\ipykernel_14000\285151773.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   상폐날짜유_df["회사명"][i]=상폐_df["회사명"][i]
#              회사명    종목코드        폐지일자
# 0          (주)금빛   45890  2021-12-20
# 1        (주)맥스로텍   87730  2021-10-08
# 2       (주)미래SCI   33110  2021-10-08
# 3        (주)아이엠텍   39230  2021-10-06
# 4      (주)에스제이케이  111820  2021-09-30
# 5        (주)에이치디  141070  2021-09-16
# 6         (주)에이팸   80440  2021-09-13
# 7      (주)이매진아시아   33430  2021-09-02
# 8      (주)이엠네트웍스   86250  2021-08-31
# 9         (주)제낙스   38160  2021-08-23
# 10        (주)지유온   33600  2021-08-11
# 11   (주)코너스톤네트웍스   65620  2021-08-09
# 12        (주)팍스넷  900080  2021-06-14
# 13         (주)퓨전  226350  2021-06-11
# 14        (주)행남사  195440  2021-06-10
# ...

# %%
상폐_df.to_csv("2021_상폐기업전처리후.csv",encoding="utf-8-sig")

# %%
상폐_전처리_df=pd.read_csv("2021_상폐기업전처리후.csv",encoding="utf-8-sig",index_col=False)
상폐_전처리_df.drop(["Unnamed: 0"],inplace=True,axis=1)
상폐_전처리_df
# Out:
#              회사명   거래소코드    회계년도    자산(*)(연결)        자산(*)    영업이익(손실)  \
# 0          (주)금빛   45890  Dec-19  102849215.0  101724359.0 -16662557.0
# 1        (주)맥스로텍  141070  Dec-19          NaN   75565720.0  -8517556.0
# 2       (주)미래SCI   28040  Dec-19   54405331.0   48377378.0  -5016986.0
# 3        (주)아이엠텍  226350  Dec-19   54274661.0   52827782.0  -2751188.0
# 4      (주)에스제이케이   80440  Dec-19   55342770.0   59723547.0  -4582413.0
# 5        (주)에이치디  102210  Dec-19  146820812.0  146820812.0  -2644956.0
# 6         (주)에이팸   73070  Dec-19  119641377.0  117564448.0  -5199063.0
# 7      (주)이매진아시아   36260  Dec-19   17924929.0   18295141.0  -3139370.0
# 8      (주)이엠네트웍스   87730  Dec-19   58841584.0   57032067.0  -4804316.0
# 9         (주)제낙스   65620  Dec-19   24780625.0   30175267.0  -6859726.0
# 10        (주)지유온  111820  Dec-19          NaN   25081604.0  -2286842.0
# 11   (주)코너스톤네트웍스   33110  Dec-19   79716591.0   64021459.0  -6822717.0
# ...

# %%
data=상폐_전처리_df

# %%
data1=data

# %%
column_list=data.columns[3:]

# %%
column_list
# Out:
# Index(['자산(*)(연결)', '자산(*)', '영업이익(손실)', '영업이익(손실)(연결)', '부채(*)(연결)', '부채(*)',
#        '자본(*)(연결)', '자본(*)', '매출액(영업수익)(*)(연결)', '매출액(영업수익)(*)', '유동자산(*)(연결)',
#        '유동자산(*)', '유동부채(*)(연결)', '유동부채(*)', '이익잉여금(*)(연결)', '이익잉여금(*)'],
#       dtype='object')

# %%
# if df_1["복리후생비(연결)(천원)"]
from tqdm import tqdm
import numpy as np
for i in tqdm(np.arange(0,len(column_list),2)):
    for j in range(data1.shape[0]):
        if np.isnan(data1[column_list[i]][j]) :
            data1[column_list[i]][j]=data1[column_list[i+1]][j]
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]C:\Users\jangd\AppData\Local\Temp\ipykernel_14000\346431395.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[column_list[i]][j]=data1[column_list[i+1]][j]
# 100%|██████████| 8/8 [00:00<00:00, 998.35it/s]

# %%
data==data1
# Out:
#      회사명  거래소코드  회계년도  자산(*)(연결)  자산(*)  영업이익(손실)  영업이익(손실)(연결)  부채(*)(연결)  \
# 0   True   True  True       True   True      True          True       True
# 1   True   True  True       True   True      True         False       True
# 2   True   True  True       True   True      True          True       True
# 3   True   True  True       True   True      True          True       True
# 4   True   True  True       True   True      True          True       True
# 5   True   True  True       True   True      True          True       True
# 6   True   True  True       True   True      True          True       True
# 7   True   True  True       True   True      True          True       True
# 8   True   True  True       True   True      True          True       True
# 9   True   True  True       True   True      True          True       True
# 10  True   True  True       True   True      True         False       True
# ...

# %%
len(data1.columns[np.arange(4,20,2)])
data1=data1.drop(data1.columns[np.arange(4,20,2)],axis=1)

# %%
data1
# Out:
#              회사명   거래소코드    회계년도    자산(*)(연결)    영업이익(손실)   부채(*)(연결)  \
# 0          (주)금빛   45890  Dec-19  102849215.0 -16662557.0  71819944.0
# 1        (주)맥스로텍  141070  Dec-19   75565720.0  -8517556.0  47403677.0
# 2       (주)미래SCI   28040  Dec-19   54405331.0  -5016986.0  37487787.0
# 3        (주)아이엠텍  226350  Dec-19   54274661.0  -2751188.0  36964987.0
# 4      (주)에스제이케이   80440  Dec-19   55342770.0  -4582413.0  42063072.0
# 5        (주)에이치디  102210  Dec-19  146820812.0  -2644956.0  35041281.0
# 6         (주)에이팸   73070  Dec-19  119641377.0  -5199063.0  74568505.0
# 7      (주)이매진아시아   36260  Dec-19   17924929.0  -3139370.0   6009557.0
# 8      (주)이엠네트웍스   87730  Dec-19   58841584.0  -4804316.0  53787729.0
# 9         (주)제낙스   65620  Dec-19   24780625.0  -6859726.0  23301868.0
# 10        (주)지유온  111820  Dec-19   25081604.0  -2286842.0  24749397.0
# 11   (주)코너스톤네트웍스   33110  Dec-19   79716591.0  -6822717.0  43119249.0
# ...

# %%
data1.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', '자산(*)(연결)', '영업이익(손실)', '부채(*)(연결)',
#        '자본(*)(연결)', '매출액(영업수익)(*)(연결)', '유동자산(*)(연결)', '유동부채(*)(연결)',
#        '이익잉여금(*)(연결)'],
#       dtype='object')

# %%
a=['회사명', '거래소코드', '회계년도', '자산', '영업이익', '부채', '자본', '매출액', '유동자산', '유동부채', '이익잉여금']

# %%
data1.columns=a

# %%
data1
# Out:
#              회사명   거래소코드    회계년도           자산        영업이익          부채  \
# 0          (주)금빛   45890  Dec-19  102849215.0 -16662557.0  71819944.0
# 1        (주)맥스로텍  141070  Dec-19   75565720.0  -8517556.0  47403677.0
# 2       (주)미래SCI   28040  Dec-19   54405331.0  -5016986.0  37487787.0
# 3        (주)아이엠텍  226350  Dec-19   54274661.0  -2751188.0  36964987.0
# 4      (주)에스제이케이   80440  Dec-19   55342770.0  -4582413.0  42063072.0
# 5        (주)에이치디  102210  Dec-19  146820812.0  -2644956.0  35041281.0
# 6         (주)에이팸   73070  Dec-19  119641377.0  -5199063.0  74568505.0
# 7      (주)이매진아시아   36260  Dec-19   17924929.0  -3139370.0   6009557.0
# 8      (주)이엠네트웍스   87730  Dec-19   58841584.0  -4804316.0  53787729.0
# 9         (주)제낙스   65620  Dec-19   24780625.0  -6859726.0  23301868.0
# 10        (주)지유온  111820  Dec-19   25081604.0  -2286842.0  24749397.0
# 11   (주)코너스톤네트웍스   33110  Dec-19   79716591.0  -6822717.0  43119249.0
# ...

# %%
data1.to_csv("2021_상폐기업_재무비율완전전처리.csv",encoding="utf-8-sig")
